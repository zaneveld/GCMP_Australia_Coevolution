# %% [markdown]
# Here, we will explore drivers of separation along the PC1 & PC2 of Unwieighted Unifrac PCA:
# Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/bdiv_all/unweighted_unifrac_emperor_pcoa_plot

# %% [markdown]
# It appears that PC1 explains separation among genera
# It appears that PC2 explains separation among compartments

# %%
cd ..
# Out:
# /Users/FJPollock/Desktop/pca_variables

# %%
#Import libraries
from os.path import join,abspath
from os import listdir

# %%
#Set file paths
input_dir = abspath("input/")
#NOTE: this is the rarified OTU table
otu_table_1000 = abspath("input/otu_table_mc2_wtax_no_pynast_failures_no_organelles_even1000.biom")
otu_table = abspath("input/otu_table_mc2_wtax_no_pynast_failures_no_organelles.biom")
mapping = abspath("input/gcmp16S_map_r20.txt")
output_dir = abspath("output/")

# %%
Image("input/unweighted_unifrac_emperor_pcoa_plot.jpg")

# %%
#Create mapping file with only the samples used in PCA
#First, create txt file with sample names from PCA: in_pca.txt
pca_only_map = join(output_dir,"pca_only_map.txt ")
# !filter_samples_from_otu_table.py -i $otu_table -o $output_dir/filter_samples_from_otu_table.biom -m $mapping --sample_id_fp $input_dir/in_pca.txt --output_mapping_fp $pca_only_map

# %% [markdown]
# # Now move to R = pca_variables_r.ipynb

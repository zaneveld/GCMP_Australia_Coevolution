# %%
setwd('..')
getwd()
# Out:
# [1] "/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis"

# %%
library(ggplot2)
library(svglite)
library(gridExtra)
library(grid)

# %%
#Import the data
#Note: weighted_unifrac_distance_tissue_prop_Colony_maximum_diameter_universal_traunch_Distances.csv is a transposed (e.g."t()") version of 3b_bdiv_australia_analysis/output/tissue_compartment_tables/bdiv_otu_table_subset_tissue.biom/distance_boxplots_weighted_unifrac/prop_Colony_maximum_diameter_universal_traunch_Distances.txt  
read.csv('input/weighted_unifrac_distance_tissue_prop_Colony_maximum_diameter_universal_traunch_Distances.csv', header=T)->data
head(data)
# Out:
#   weighted_unifrac_distance  size
# 1                 0.7764049 00_20
# 2                 0.9820920 00_20
# 3                 0.9082718 00_20
# 4                 0.9118367 00_20
# 5                 0.7071827 00_20
# 6                 0.8185304 00_20

# %%
ggplot(data, aes(x=size, y=as.numeric(as.character(weighted_unifrac_distance)))) + 
    geom_boxplot()
# Out:
# Error in file(con, "rb"): cannot open the connection
# plot without title

# %%
summary(aov(as.numeric(as.character(weighted_unifrac_distance))~size,data))
# Out:
#               Df Sum Sq Mean Sq F value Pr(>F)
# size           4   1.69  0.4236   20.71 <2e-16 ***
# Residuals   5313 108.67  0.0205
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
TukeyHSD(aov(as.numeric(as.character(weighted_unifrac_distance))~size,data))
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = as.numeric(as.character(weighted_unifrac_distance)) ~ size, data = data)
#
# $size
#                      diff          lwr          upr     p adj
# 20_40-00_20   0.039799621  0.023296354  0.056302889 0.0000000
# 40_60-00_20  -0.023727139 -0.051456171  0.004001893 0.1340480
# 60_80-00_20   0.030904815  0.005495331  0.056314299 0.0080930
# 80_100-00_20 -0.021281905 -0.037416419 -0.005147391 0.0029719
# 40_60-20_40  -0.063526760 -0.094411742 -0.032641778 0.0000002
# 60_80-20_40  -0.008894806 -0.037715368  0.019925755 0.9174301
# 80_100-20_40 -0.061081527 -0.082183789 -0.039979265 0.0000000
# 60_80-40_60   0.054631954  0.018201662  0.091062246 0.0004172
# 80_100-40_60  0.002445234 -0.028244290  0.033134757 0.9995046
# 80_100-60_80 -0.052186720 -0.080797723 -0.023575717 0.0000066

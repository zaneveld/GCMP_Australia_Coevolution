# %% [markdown]
# # 16S_procedure_3b_bdiv_australia_analysis: Here we will test the hypothesis that compartments have distinct microbial communities via beta-diversity assessment
#
# # NOTE: This analysis uses the updated Greengenes constrained tree.

# %%
cd ..
# Out:
# /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis

# %%
#Import libraries
from os.path import join,abspath
from os import listdir

# %%
#Set file paths
input_dir = abspath("input/")
otu_table = abspath("input/otu_table_mc2_wtax_no_pynast_failures_no_organelles.biom")
tree_fp = abspath("input/gg_constrained_rep_set_fastttree.tre")
mapping = abspath("input/gcmp16S_map_r22.txt")
output_dir = abspath("output/")

#Preference file indicating that Curtis-Brays distance should also be calculated by beta_diversity
bc_prefs_fp = abspath("input/bdiv_bc_prefs.txt")

# %%
# Summarize BIOM
# !biom summarize-table -i $otu_table
# Out:
# Num samples: 692
# Num observations: 129305
# Total count: 9441738
# Table density (fraction of non-zero values): 0.006
#
# Counts/sample summary:
#  Min: 2.0
#  Max: 38523.0
#  Median: 14010.000
#  Mean: 13644.130
#  Std. dev.: 7564.457
#  Sample Metadata Categories: None provided
#  Observation Metadata Categories: taxonomy
#
# Counts/sample detail:
#  E7.17.Pla.sine.1.20150622.M: 2.0
#  E3.17.Ech.mamm.1.20150127.S: 3.0
#  E10.17.Fav.pali.2.20150630.T: 5.0
#  E7.17.Fav.spB.1.20150623.T: 7.0
#  E3.17.Ech.horr.1.20150123.M: 8.0
#  E3.15.Dip.heli.2.20150120.T: 9.0
#  E10.Cyp.sera.1.20150628.M: 17.0
#  E10.17.Fav.pali.1.20150630.T: 17.0
#  E3.Out.Mil.sp.2.20150125.M: 24.0
#  E10.17.Fav.pali.1.20150630.M: 36.0
#  E10.17.Fav.pali.2.20150630.S: 41.0
#  E10.Cyp.sera.2.20150628.T: 42.0
#  E1.6.Acr.sp.1.20140726.T: 42.0
#  E3.5.Gal.astr.2.20150127.T: 53.0
#  E10.Ser.cali.2.20150627.T: 66.0
#  E10.Alv.alli.1.20150628.S: 96.0
#  E10.Ser.cali.1.20150627.T: 102.0
#  E10.17.Fav.pali.2.20150630.M: 127.0
#  E10.17.Fav.abdi.2.20150630.T: 165.0
#  E7.17.Gon.edwa.2.20150623.S: 197.0
#  E10.17.Fav.pali.3.20150630.T: 200.0
#  E10.17.Fav.pali.3.20150630.S: 252.0
#  E10.17.Fav.pali.3.20150630.M: 276.0
#  E3.6.Acr.hyac.3.20150106.S: 470.0
#  E10.Ser.cali.3.20150627.T: 522.0
#  E10.10.Sty.pist.2.20150630.S: 566.0
#  E3.6.Acr.hyac.1.20150120.T: 576.0
#  E3.2.Tur.reni.2.20150124.S: 627.0
#  E7.7.Pav.vari.1.20150622.T: 690.0
#  E3.2.Tur.reni.2.20150124.T: 788.0
#  E3.6.Acr.hyac.4.20150106.M: 941.0
#  E10.Ser.cali.3.20150627.S: 1004.0
#  E3.10.Sty.pist.2.20150124.S: 1005.0
#  E1.6.Acr.sp.1.20140726.M: 1009.0
#  E7.10.Poc.dami.2.20150621.T: 1033.0
#  E7.10.Poc.dami.1.20150621.T: 1114.0
#  E3.6.Acr.hyac.1.20150105.M: 24644.0
#  E10.17.Gon.favu.1.20150629.M: 24699.0
#  E1.Out.Mil.sp.1.20140814.T: 24730.0
#  E10.Acr.pali.3.20150627.M: 24768.0
#  E1.14.Phy.lich.1.20140811.S: 24846.0
#  E7.17.Fav.spB.1.20150623.M: 25081.0
#  E3.15.Dip.heli.1.20150120.S: 25191.0
#  E3.6.Acr.hyac.2.20150123.M: 25208.0
#  E1.11.Psa.digi.1.20140807.T: 25567.0
#  E3.6.Acr.hyac.3.20150123.M: 25664.0
#  E10.Sed.1.20150627: 25668.0
#  E7.17.Mer.ampl.3.20150621.M: 25690.0
#  E7.3.Por.loba.1.20150619.M: 25879.0
#  E3.6.Acr.hyac.1.20150106.M: 25937.0
#  E3.Out.Pal.caes.2.20150125.M: 26230.0
#  E10.Acr.cyth.2.20150627.T: 26327.0
#  E10.17.Fav.abdi.1.20150630.M: 26462.0
#  E1.4.Pac.rugo.1.20140814.S: 26511.0
#  E7.17.Ech.lame.1.20150620.M: 26583.0
#  E7.6.Mon.aequ.4.20150620.M: 26690.0
#  E7.6.Mon.aequ.2.20150620.M: 26877.0
#  E7.6.Acr.hyac.2.20150622.M: 26934.0
#  E7.5.Gal.astr.1.20150622.M: 27075.0
#  E7.17.Mer.ampl.1.20150621.M: 27128.0
#  E10.Acr.cyth.2.20150627.M: 27180.0
#  E3.15.Dip.heli.2.20150121.S: 27242.0
#  E3.15.Dip.heli.3.20150121.S: 27387.0
#  E1.3.Por.loba.1.20140905.S: 27482.0
#  E7.6.Acr.hyac.1.20150622.M: 27595.0
#  E1.11.Fun.sp.1.20140811.T: 27603.0
#  E3.Out.Mil.sp.1.20150125.T: 27894.0
#  E7.10.Ser.cali.1.20150622.M: 28052.0
#  E10.Aca.hill.2.20150629.M: 28263.0
#  E3.15.Dip.heli.1.20150121.M: 28304.0
#  E10.Alv.alli.1.20150628.M: 28318.0
#  E3.19.Sym.sp.2.20150125.M: 28347.0
#  E3.6.Acr.hyac.2.20150105.M: 28794.0
#  E3.Out.Mil.sp.2.20150125.T: 28870.0
#  E3.17.Ech.mamm.1.20150123.M: 28896.0
#  E7.19.Lob.hemp.1.20150621.M: 29541.0
#  E3.11.Fun.sp.1.20150125.M: 30168.0
#  E10.Alv.alli.2.20150628.M: 31070.0
#  E3.Out.Mil.sp.2.20150125.S: 31091.0
#  E1.11.Fun.sp.1.20140811.M: 32780.0
#  E3.Out.Mil.sp.1.20150125.S: 33141.0
#  E1.11.Fun.sp.1.20140811.S: 35581.0
#  E10.Acr.cyth.1.20150627.M: 38523.0

# %%
#Subsampling to 1000 loses 31 samples, but this seems reasonable.
depth=1000

# %%
#Run beta diversity on all samples
bdiv_dir_all = join(output_dir,'bdiv_all')
# !beta_diversity_through_plots.py -i $otu_table -o $bdiv_dir_all -m $mapping -p $bc_prefs_fp --force -t $tree_fp -e $depth
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.203636422742 and the largest is 17.4947292856.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -1.26986829308 and the largest is 26.0525845582.
#   RuntimeWarning

# %%
#Create OTU table with only Scleractinian corals
#Export Sceleractinian coral compartment specific biom file
subset_output = join(output_dir,'compartment_tables')
# !filter_samples_from_otu_table.py -i $otu_table -o $subset_output/otu_table_subset_scleractinian.biom -m $mapping -s 'taxonomy_string_to_order:Cnidaria_Anthozoa_Scleractinia'
# !biom summarize-table -i $subset_output/otu_table_subset_scleractinian.biom -o $subset_output/otu_table_subset_scleractinian_summary.txt

# %%
#Run beta diversity on only Scleractinian samples
subset_output = join(output_dir,'compartment_tables')
# !beta_diversity_through_plots.py -i $subset_output/otu_table_subset_scleractinian.biom -o $subset_output/Scleractinian_only -m $mapping -p $bc_prefs_fp --force -t $tree_fp -e $depth
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.218644592699 and the largest is 16.6966060546.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -1.18331362097 and the largest is 24.4731203701.
#   RuntimeWarning

# %%
# Test for significant differences in community composition among compartments
scleractinian_subset_output = join(output_dir,'compartment_tables','Scleractinian_only')

n_permutations = 1000
categories = 'BiologicalMatter'
for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
    curr_dm = join(scleractinian_subset_output,"%s_dm.txt" %metric)   
    for curr_cat in categories.split(","):
        print "curr_cat: %s" %curr_cat
        print "curr_metric: %s" %metric
        curr_compare_cat_output_dir = join(scleractinian_subset_output,"compare_categories_%s_%s" %(curr_cat,metric))
        # !compare_categories.py -i $curr_dm -o $curr_compare_cat_output_dir -m $mapping -c $curr_cat --method adonis -n $n_permutations
        the_result = join(curr_compare_cat_output_dir,"adonis_results.txt")
        # !head -n 30 $the_result
# Out:
# curr_cat: BiologicalMatter
# curr_metric: bray_curtis
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model     R2   Pr(>F)
# qiime.data$map[[opts$category]]   3    10.706  3.5687  7.8026 0.0369 0.000999
# Residuals                       611   279.454  0.4574         0.9631
# Total                           614   290.160                 1.0000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: BiologicalMatter
# curr_metric: weighted_unifrac
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   3    10.029  3.3431  13.498 0.06216 0.000999
# Residuals                       611   151.325  0.2477         0.93784
# Total                           614   161.355                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: BiologicalMatter
# curr_metric: unweighted_unifrac
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   3     6.844 2.28138  6.0842 0.02901 0.000999
# Residuals                       611   229.105 0.37497         0.97099
# Total                           614   235.949                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
#Boxplot summaries: compartments

scleractinian_subset_output = join(output_dir,'compartment_tables','Scleractinian_only')
n_permutations = 1000
categories = 'BiologicalMatter'
for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
    curr_dm = join(scleractinian_subset_output,"%s_dm.txt" %metric)
    curr_boxplot_output_dir = join(scleractinian_subset_output,"distance_boxplots_all_within_%s" %metric)
    # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_individual_within  -n $n_permutations --sort median
    curr_boxplot_output_dir = join(scleractinian_subset_output,"distance_boxplots_%s" %metric)
    # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_all_within --suppress_all_between -n $n_permutations --sort median
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")

# %%
#Boxplot summaries: compartments

scleractinian_subset_output = join(output_dir,'compartment_tables','Scleractinian_only')
n_permutations = 1000
categories = 'BiologicalMatter'
for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
    curr_dm = join(scleractinian_subset_output,"%s_dm.txt" %metric)
    curr_boxplot_output_dir = join(scleractinian_subset_output,"distance_boxplots_all_comparisons_%s" %metric)
    # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20  -n $n_permutations --sort median
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")

# %%
#Create OTU table with only Scleractinian corals (NOTE: NOW WE EXCLUDE Whole_Coral sample)
#Export Sceleractinian coral compartment specific biom file (NOTE: NOW WE EXCLUDE Whole_Coral sample)
subset_output = join(output_dir,'compartment_tables')
# !filter_samples_from_otu_table.py -i $subset_output/otu_table_subset_scleractinian.biom -o $subset_output/otu_table_subset_scleractinian_no_whole_coral.biom -m $mapping -s 'BiologicalMatter:*,!Whole_Coral'
# !biom summarize-table -i $subset_output/otu_table_subset_scleractinian_no_whole_coral.biom -o $subset_output/otu_table_subset_scleractinian_no_whole_coral_summary.txt

# %%
#Run beta diversity on rarified (1000) subset of Scleractinian corals (NOTE: NOW WE EXCLUDE Whole_Coral sample)
tissue_otu_table_dir = join(output_dir,"compartment_tables")
depth = 1000

# !beta_diversity_through_plots.py -i $subset_output/otu_table_subset_scleractinian_no_whole_coral.biom -o $subset_output/Scleractinian_only_no_whole_coral -m $mapping -p $bc_prefs_fp -e $depth -f -t $tree_fp
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.19072619308 and the largest is 16.6467128078.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -1.1786781633 and the largest is 24.4562972479.
#   RuntimeWarning

# %%
# Test for significant differences in community composition among compartments
scleractinian_subset_output = join(output_dir,'compartment_tables','Scleractinian_only_no_whole_coral')

n_permutations = 1000
categories = 'BiologicalMatter'
for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
    curr_dm = join(scleractinian_subset_output,"%s_dm.txt" %metric)   
    for curr_cat in categories.split(","):
        print "curr_cat: %s" %curr_cat
        print "curr_metric: %s" %metric
        curr_compare_cat_output_dir = join(scleractinian_subset_output,"compare_categories_%s_%s" %(curr_cat,metric))
        # !compare_categories.py -i $curr_dm -o $curr_compare_cat_output_dir -m $mapping -c $curr_cat --method adonis -n $n_permutations
        the_result = join(curr_compare_cat_output_dir,"adonis_results.txt")
        # !head -n 30 $the_result
# Out:
# curr_cat: BiologicalMatter
# curr_metric: bray_curtis
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   2    10.159  5.0794  11.104 0.03507 0.000999
# Residuals                       611   279.506  0.4575         0.96493
# Total                           613   289.665                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: BiologicalMatter
# curr_metric: weighted_unifrac
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   2     9.723  4.8617  19.656 0.06045 0.000999
# Residuals                       611   151.127  0.2473         0.93955
# Total                           613   160.851                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: BiologicalMatter
# curr_metric: unweighted_unifrac
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   2     6.675  3.3374  8.8889 0.02827 0.000999
# Residuals                       611   229.405  0.3755         0.97173
# Total                           613   236.080                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
#Boxplot summaries: compartments

scleractinian_subset_output = join(output_dir,'compartment_tables','Scleractinian_only_no_whole_coral')
n_permutations = 1000
categories = 'BiologicalMatter'
for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
    curr_dm = join(scleractinian_subset_output,"%s_dm.txt" %metric)
    curr_boxplot_output_dir = join(scleractinian_subset_output,"distance_boxplots_all_within_%s" %metric)
    # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_individual_within  -n $n_permutations --sort median
    curr_boxplot_output_dir = join(scleractinian_subset_output,"distance_boxplots_%s" %metric)
    # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_all_within --suppress_all_between -n $n_permutations --sort median
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")

# %%
#Export Sceleractinian coral compartment specific biom files (i.e. coral t, m and s)
subset_output = join(output_dir,'compartment_tables')
# !filter_samples_from_otu_table.py -i $subset_output/otu_table_subset_scleractinian.biom -o $subset_output/otu_table_subset_mucus.biom -m $mapping -s 'sample_type:Coral_Mucus'
# !filter_samples_from_otu_table.py -i $subset_output/otu_table_subset_scleractinian.biom -o $subset_output/otu_table_subset_skeleton.biom -m $mapping -s 'sample_type:Coral_Skeleton'
# !filter_samples_from_otu_table.py -i $subset_output/otu_table_subset_scleractinian.biom -o $subset_output/otu_table_subset_tissue.biom -m $mapping -s 'sample_type:Coral_Tissue'

# %%
#Summarize BIOM to confirm filter functioned correctly
# !biom summarize-table -i $subset_output/otu_table_subset_mucus.biom -o $subset_output/otu_table_subset_mucus_summary.txt
# !biom summarize-table -i $subset_output/otu_table_subset_tissue.biom -o $subset_output/otu_table_subset_tissue_summary.txt
# !biom summarize-table -i $subset_output/otu_table_subset_skeleton.biom -o $subset_output/otu_table_subset_skeleton_summary.txt

# %% [markdown]
# #Summaries look good.

# %%
#Run beta diversity on rarified (1000) subset of each sample type
tissue_otu_table_dir = join(output_dir,"compartment_tables")
depth = 1000

for c in listdir(tissue_otu_table_dir):
    if not c.endswith(".biom"):
        continue
    curr_bdiv_dir = join(tissue_otu_table_dir,'bdiv_%s' %c)
    curr_otu_table = join(tissue_otu_table_dir,c)
    # !beta_diversity_through_plots.py -i $curr_otu_table -o $curr_bdiv_dir -m $mapping -p $bc_prefs_fp -e $depth -f -t $tree_fp
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.100459226024 and the largest is 9.60549079436.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.23079800206 and the largest is 9.67522628678.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.201274352463 and the largest is 16.8005403628.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -1.20362918709 and the largest is 24.4263721713.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.113652116153 and the largest is 5.82405629261.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.191948176139 and the largest is 11.0031160197.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0858951706045 and the largest is 7.89900539945.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.471949705422 and the largest is 9.81978502459.
#   RuntimeWarning

# %%
#Check for differences among mapping categories within a given compartment
tissue_otu_table_dir = join(output_dir,"compartment_tables")

n_permutations = 1000
categories = 'host_clade_sensu_fukami,reef_name,field_host_name,field_host_genus_id,photosynthetically_active_radiation,visibility,turf_contact_percent,n_macroalgal_contacts,cyanobacteria_percent,cyanobacteria_contact,binary_turf_contact,binary_macroalgal_contact'
for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
#    curr_bdiv_dir = join(tissue_otu_table_dir,'bdiv_%s' %c)
    curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
    print listdir(curr_bdiv_dir)
    curr_otu_table = join(tissue_otu_table_dir,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)   
        for curr_cat in categories.split(","):
            print "curr_cat: %s" %curr_cat
            print "curr_metric: %s" %metric
            print "curr_category: %s" %c
            curr_compare_cat_output_dir = join(curr_bdiv_dir,"compare_categories_%s_%s" %(curr_cat,metric))
            # !compare_categories.py -i $curr_dm -o $curr_compare_cat_output_dir -m $mapping -c $curr_cat --method adonis -n $n_permutations
            the_result = join(curr_compare_cat_output_dir,"adonis_results.txt")
            # !head -n 30 $the_result
# Out:
# ['bray_curtis_dm.txt', 'bray_curtis_emperor_pcoa_plot', 'bray_curtis_pc.txt', 'compare_categories_field_host_clade_sensu_fukami_bray_curtis', 'compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_field_host_genus_id_bray_curtis', 'compare_categories_field_host_genus_id_unweighted_unifrac', 'compare_categories_field_host_genus_id_weighted_unifrac', 'compare_categories_field_host_name_bray_curtis', 'compare_categories_field_host_name_unweighted_unifrac', 'compare_categories_field_host_name_weighted_unifrac', 'compare_categories_reef_name.x_bray_curtis', 'compare_categories_reef_name.x_unweighted_unifrac', 'compare_categories_reef_name.x_weighted_unifrac', 'log_20161031170530.txt', 'otu_table_subset_mucus_even1000.biom', 'unweighted_unifrac_dm.txt', 'unweighted_unifrac_emperor_pcoa_plot', 'unweighted_unifrac_pc.txt', 'weighted_unifrac_dm.txt', 'weighted_unifrac_emperor_pcoa_plot', 'weighted_unifrac_pc.txt']
# curr_cat: host_clade_sensu_fukami
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_mucus.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  12     8.813 0.73442   1.777 0.09903 0.000999
# Residuals                       194    80.180 0.41330         0.90097
# Total                           206    88.993                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: reef_name
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_mucus.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  20    17.292 0.86461  2.2429 0.19431 0.000999
# Residuals                       186    71.701 0.38549         0.80569
# Total                           206    88.993                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_name
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_mucus.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  52    30.629 0.58901  1.5541 0.34417 0.000999
# Residuals                       154    58.365 0.37899         0.65583
# Total                           206    88.993                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_genus_id
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_mucus.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  30    19.592 0.65306  1.6562 0.22015 0.000999
# Residuals                       176    69.401 0.39433         0.77985
# Total                           206    88.993                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: photosynthetically_active_radiation
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_mucus.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   5     3.869 0.77378  1.8271 0.04347 0.000999
# Residuals                       201    85.124 0.42350         0.95653
# Total                           206    88.993                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: visibility
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_mucus.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  13    12.395 0.95344  2.4023 0.13928 0.000999
# Residuals                       193    76.598 0.39688         0.86072
# Total                           206    88.993                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: turf_contact_percent
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_mucus.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  12    11.644 0.97037  2.4338 0.13085 0.000999
# Residuals                       194    77.349 0.39871         0.86915
# Total                           206    88.993                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: n_macroalgal_contacts
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_mucus.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   2     1.334 0.66692  1.5521 0.01499 0.004995
# Residuals                       204    87.659 0.42970         0.98501
# Total                           206    88.993                 1.00000
#
# qiime.data$map[[opts$category]] **
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: cyanobacteria
# Total                           206    73.340                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: binary_turf_contact
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_mucus.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   2     3.688 1.84391  5.4006 0.05028 0.000999
# Residuals                       204    69.652 0.34143         0.94972
# Total                           206    73.340                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: binary_macroalgal_contact
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_mucus.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model    R2   Pr(>F)
# qiime.data$map[[opts$category]]   1     0.586 0.58638  1.6523 0.008 0.007992 **
# Residuals                       205    72.753 0.35489         0.992
# Total                           206    73.340                 1.000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ['.DS_Store', 'bray_curtis_dm.txt', 'bray_curtis_emperor_pcoa_plot', 'bray_curtis_pc.txt', 'compare_categories_field_host_clade_sensu_fukami_bray_curtis', 'compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_field_host_genus_id_bray_curtis', 'compare_categories_field_host_genus_id_unweighted_unifrac', 'compare_categories_field_host_genus_id_weighted_unifrac', 'compare_categories_field_host_name_bray_curtis', 'compare_categories_field_host_name_unweighted_unifrac', 'compare_categories_field_host_name_weighted_unifrac', 'compare_categories_reef_name.x_bray_curtis', 'compare_categories_reef_name.x_unweighted_unifrac', 'compare_categories_reef_name.x_weighted_unifrac', 'log_20161031170717.txt', 'otu_table_subset_scleractinian_even1000.biom', 'unweighted_unifrac_dm.txt', 'unweighted_unifrac_emperor_pcoa_plot', 'unweighted_unifrac_pc.txt', 'weighted_unifrac_dm.txt', 'weighted_unifrac_emperor_pcoa_plot', 'weighted_unifrac_pc.txt']
# curr_cat: host_clade_sensu_fukami
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model     R2   Pr(>F)
# qiime.data$map[[opts$category]]  12    19.792 1.64934  3.6721 0.0682 0.000999
# Residuals                       602   270.393 0.44916         0.9318
# Total                           614   290.185                 1.0000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: reef_name
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  20     22.01 1.10050  2.4376 0.07585 0.000999
# Residuals                       594    268.18 0.45147         0.92415
# Total                           614    290.19                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_name
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model    R2   Pr(>F)
# qiime.data$map[[opts$category]]  54    55.717 1.03179  2.4643 0.192 0.000999
# Residuals                       560   234.469 0.41869         0.808
# Total                           614   290.185                 1.000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_genus_id
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  31    39.607 1.27764  2.9726 0.13649 0.000999
# Residuals                       583   250.578 0.42981         0.86351
# Total                           614   290.185                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: photosynthetically_active_radiation
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   5     5.284 1.05690  2.2592 0.01821 0.000999
# Residuals                       609   284.901 0.46782         0.98179
# Total                           614   290.185                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: visibility
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  13    15.125 1.16343  2.5421 0.05212 0.000999
# Residuals                       601   275.061 0.45767         0.94788
# Total                           614   290.185                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: turf_contact_percent
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  12    13.923 1.16029  2.5284 0.04798 0.000999
# Residuals                       602   276.262 0.45891         0.95202
# Total                           614   290.185                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: n_macroalgal_contacts
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   2     1.455 0.72743  1.5419 0.00501 0.000999
# Residuals                       612   288.730 0.47178         0.99499
# Total                           614   290.185                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: cyanobacteria_percent
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   4     3.924 0.98110  2.0907 0.01352 0.000999
# Residuals                       610   286.261 0.46928         0.98648
# Total                           614   290.185                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: cyanobacteria_contact
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   1     2.216 2.21632  4.7179 0.00764 0.000999
# Residuals                       613   287.969 0.46977         0.99236
# Total                           614   290.185                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: binary_turf_contact
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   2     6.387  3.1937  6.8871 0.02201 0.000999
# Residuals                       612   283.798  0.4637         0.97799
# Total                           614   290.185                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: binary_macroalgal_contact
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   1     1.008 1.00808  2.1369 0.00347 0.000999
# Residuals                       613   289.177 0.47174         0.99653
# Total                           614   290.185                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: host_clade_sensu_fukami
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  12    17.188 1.43234  5.9777 0.10647 0.000999
# Residuals                       602   144.247 0.23961         0.89353
# Total                           614   161.435                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: reef_name
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  20    14.701 0.73507  2.9757 0.09107 0.000999
# Residuals                       594   146.734 0.24703         0.90893
# Total                           614   161.435                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_name
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  54    35.697 0.66106  2.9442 0.22113 0.000999
# Residuals                       560   125.737 0.22453         0.77887
# Total                           614   161.435                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_genus_id
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  31    28.158 0.90833  3.9733 0.17442 0.000999
# Residuals                       583   133.277 0.22861         0.82558
# Total                           614   161.435                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: photosynthetically_active_radiation
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   5     2.479 0.49588  1.8998 0.01536 0.000999
# Residuals                       609   158.956 0.26101         0.98464
# Total                           614   161.435                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: visibility
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  13    10.384 0.79879  3.1782 0.06432 0.000999
# Residuals                       601   151.051 0.25133         0.93568
# Total                           614   161.435                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ...
# Residuals                       193    52.862 0.27389         0.97172
# Total                           198    54.400                 1.00000
# curr_cat: visibility
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  13     5.485 0.42192  1.5958 0.10083 0.000999
# Residuals                       185    48.915 0.26440         0.89917
# Total                           198    54.400                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: turf_contact_percent
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2  Pr(>F)
# qiime.data$map[[opts$category]]  12     3.983 0.33194  1.2246 0.07322 0.05694 .
# Residuals                       186    50.417 0.27106         0.92678
# Total                           198    54.400                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: n_macroalgal_contacts
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# qiime.data$map[[opts$category]]   2     0.616 0.30801  1.1225 0.01132 0.2887
# Residuals                       196    53.784 0.27441         0.98868
# Total                           198    54.400                 1.00000
# curr_cat: cyanobacteria_percent
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2  Pr(>F)
# qiime.data$map[[opts$category]]   4     1.412 0.35307  1.2927 0.02596 0.07692 .
# Residuals                       194    52.988 0.27313         0.97404
# Total                           198    54.400                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: cyanobacteria_contact
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   1     0.576 0.57583  2.1076 0.01059 0.007992
# Residuals                       197    53.824 0.27322         0.98941
# Total                           198    54.400                 1.00000
#
# qiime.data$map[[opts$category]] **
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: binary_turf_contact
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   2     1.902 0.95095  3.5504 0.03496 0.000999
# Residuals                       196    52.498 0.26785         0.96504
# Total                           198    54.400                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: binary_macroalgal_contact
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2  Pr(>F)
# qiime.data$map[[opts$category]]   1      0.42 0.42013  1.5333 0.00772 0.08292 .
# Residuals                       197     53.98 0.27401         0.99228
# Total                           198     54.40                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: host_clade_sensu_fukami
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  12     9.288 0.77397  2.1689 0.12275 0.000999
# Residuals                       186    66.375 0.35685         0.87725
# Total                           198    75.663                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: reef_name
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  20     9.686 0.48429  1.3066 0.12801 0.000999
# Residuals                       178    65.977 0.37066         0.87199
# Total                           198    75.663                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_name
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  51    26.265 0.51500  1.5326 0.34713 0.000999
# Residuals                       147    49.398 0.33604         0.65287
# Total                           198    75.663                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_genus_id
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  30    18.207 0.60689  1.7745 0.24063 0.000999
# Residuals                       168    57.456 0.34200         0.75937
# Total                           198    75.663                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: photosynthetically_active_radiation
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# qiime.data$map[[opts$category]]   5     2.069 0.41371   1.085 0.02734 0.1149
# Residuals                       193    73.594 0.38132         0.97266
# Total                           198    75.663                 1.00000
# curr_cat: visibility
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  13     6.214 0.47803  1.2734 0.08213 0.000999
# Residuals                       185    69.448 0.37540         0.91787
# Total                           198    75.663                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: turf_contact_percent
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  12     5.923 0.49355  1.3163 0.07828 0.000999
# Residuals                       186    69.740 0.37495         0.92172
# Total                           198    75.663                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: n_macroalgal_contacts
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# qiime.data$map[[opts$category]]   2     0.783 0.39162  1.0251 0.01035 0.3217
# Residuals                       196    74.879 0.38204         0.98965
# Total                           198    75.663                 1.00000
# curr_cat: cyanobacteria_percent
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   4     1.986 0.49652  1.3074 0.02625 0.003996
# Residuals                       194    73.677 0.37978         0.97375
# Total                           198    75.663                 1.00000
#
# qiime.data$map[[opts$category]] **
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: cyanobacteria_contact
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   1     0.854 0.85357  2.2478 0.01128 0.001998
# Residuals                       197    74.809 0.37974         0.98872
# Total                           198    75.663                 1.00000
#
# qiime.data$map[[opts$category]] **
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: binary_turf_contact
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   2     1.921 0.96066  2.5534 0.02539 0.000999
# Residuals                       196    73.741 0.37623         0.97461
# Total                           198    75.663                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: binary_macroalgal_contact
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# qiime.data$map[[opts$category]]   1     0.437 0.43656  1.1433 0.00577 0.1439
# Residuals                       197    75.226 0.38186         0.99423
# Total                           198    75.663                 1.00000
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-e78008f84888> in <module>()
#       9 #    curr_bdiv_dir = join(tissue_otu_table_dir,'bdiv_%s' %c)
#      10     curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
# ---> 11     print listdir(curr_bdiv_dir)
#      12     curr_otu_table = join(tissue_otu_table_dir,c)
#      13     for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
#
# OSError: [Errno 20] Not a directory: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/compartment_tables/otu_table_subset_mucus.biom'

# %%
#Boxplot summaries: pre
tissue_otu_table_dir = join(output_dir,"compartment_tables")
n_permutations = 1000
categories = 'host_clade_sensu_fukami,reef_name,field_host_name,field_host_genus_id,photosynthetically_active_radiation,visibility,turf_contact_percent,n_macroalgal_contacts,cyanobacteria_percent,cyanobacteria_contact,binary_turf_contact,binary_macroalgal_contact'
for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
#    curr_bdiv_dir = join(tissue_otu_table_dir,'bdiv_%s' %c)
    curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
    print listdir(curr_bdiv_dir)
    curr_otu_table = join(tissue_otu_table_dir,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_all_within_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_individual_within  -n $n_permutations --sort median
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_all_within --suppress_all_between -n $n_permutations --sort median
# Out:
# ['.DS_Store', 'bray_curtis_dm.txt', 'bray_curtis_emperor_pcoa_plot', 'bray_curtis_pc.txt', 'compare_categories_binary_macroalgal_contact_bray_curtis', 'compare_categories_binary_macroalgal_contact_unweighted_unifrac', 'compare_categories_binary_macroalgal_contact_weighted_unifrac', 'compare_categories_binary_turf_contact_bray_curtis', 'compare_categories_binary_turf_contact_unweighted_unifrac', 'compare_categories_binary_turf_contact_weighted_unifrac', 'compare_categories_cyanobacteria_contact_bray_curtis', 'compare_categories_cyanobacteria_contact_unweighted_unifrac', 'compare_categories_cyanobacteria_contact_weighted_unifrac', 'compare_categories_cyanobacteria_percent_bray_curtis', 'compare_categories_cyanobacteria_percent_unweighted_unifrac', 'compare_categories_cyanobacteria_percent_weighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_bray_curtis', 'compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_field_host_genus_id_bray_curtis', 'compare_categories_field_host_genus_id_unweighted_unifrac', 'compare_categories_field_host_genus_id_weighted_unifrac', 'compare_categories_field_host_name_bray_curtis', 'compare_categories_field_host_name_unweighted_unifrac', 'compare_categories_field_host_name_weighted_unifrac', 'compare_categories_host_clade_sensu_fukami_bray_curtis', 'compare_categories_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_n_macroalgal_contacts_bray_curtis', 'compare_categories_n_macroalgal_contacts_unweighted_unifrac', 'compare_categories_n_macroalgal_contacts_weighted_unifrac', 'compare_categories_photosynthetically_active_radiation_bray_curtis', 'compare_categories_photosynthetically_active_radiation_unweighted_unifrac', 'compare_categories_photosynthetically_active_radiation_weighted_unifrac', 'compare_categories_reef_name.x_bray_curtis', 'compare_categories_reef_name.x_unweighted_unifrac', 'compare_categories_reef_name.x_weighted_unifrac', 'compare_categories_reef_name_bray_curtis', 'compare_categories_reef_name_unweighted_unifrac', 'compare_categories_reef_name_weighted_unifrac', 'compare_categories_turf_contact_percent_bray_curtis', 'compare_categories_turf_contact_percent_unweighted_unifrac', 'compare_categories_turf_contact_percent_weighted_unifrac', 'compare_categories_visibility_bray_curtis', 'compare_categories_visibility_unweighted_unifrac', 'compare_categories_visibility_weighted_unifrac', 'log_20161031170530.txt', 'otu_table_subset_mucus_even1000.biom', 'unweighted_unifrac_dm.txt', 'unweighted_unifrac_emperor_pcoa_plot', 'unweighted_unifrac_pc.txt', 'weighted_unifrac_dm.txt', 'weighted_unifrac_emperor_pcoa_plot', 'weighted_unifrac_pc.txt']
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# ['.DS_Store', 'bray_curtis_dm.txt', 'bray_curtis_emperor_pcoa_plot', 'bray_curtis_pc.txt', 'compare_categories_binary_macroalgal_contact_bray_curtis', 'compare_categories_binary_macroalgal_contact_unweighted_unifrac', 'compare_categories_binary_macroalgal_contact_weighted_unifrac', 'compare_categories_binary_turf_contact_bray_curtis', 'compare_categories_binary_turf_contact_unweighted_unifrac', 'compare_categories_binary_turf_contact_weighted_unifrac', 'compare_categories_cyanobacteria_contact_bray_curtis', 'compare_categories_cyanobacteria_contact_unweighted_unifrac', 'compare_categories_cyanobacteria_contact_weighted_unifrac', 'compare_categories_cyanobacteria_percent_bray_curtis', 'compare_categories_cyanobacteria_percent_unweighted_unifrac', 'compare_categories_cyanobacteria_percent_weighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_bray_curtis', 'compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_field_host_genus_id_bray_curtis', 'compare_categories_field_host_genus_id_unweighted_unifrac', 'compare_categories_field_host_genus_id_weighted_unifrac', 'compare_categories_field_host_name_bray_curtis', 'compare_categories_field_host_name_unweighted_unifrac', 'compare_categories_field_host_name_weighted_unifrac', 'compare_categories_host_clade_sensu_fukami_bray_curtis', 'compare_categories_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_n_macroalgal_contacts_bray_curtis', 'compare_categories_n_macroalgal_contacts_unweighted_unifrac', 'compare_categories_n_macroalgal_contacts_weighted_unifrac', 'compare_categories_photosynthetically_active_radiation_bray_curtis', 'compare_categories_photosynthetically_active_radiation_unweighted_unifrac', 'compare_categories_photosynthetically_active_radiation_weighted_unifrac', 'compare_categories_reef_name.x_bray_curtis', 'compare_categories_reef_name.x_unweighted_unifrac', 'compare_categories_reef_name.x_weighted_unifrac', 'compare_categories_reef_name_bray_curtis', 'compare_categories_reef_name_unweighted_unifrac', 'compare_categories_reef_name_weighted_unifrac', 'compare_categories_turf_contact_percent_bray_curtis', 'compare_categories_turf_contact_percent_unweighted_unifrac', 'compare_categories_turf_contact_percent_weighted_unifrac', 'compare_categories_visibility_bray_curtis', 'compare_categories_visibility_unweighted_unifrac', 'compare_categories_visibility_weighted_unifrac', 'log_20161031170717.txt', 'otu_table_subset_scleractinian_even1000.biom', 'unweighted_unifrac_dm.txt', 'unweighted_unifrac_emperor_pcoa_plot', 'unweighted_unifrac_pc.txt', 'weighted_unifrac_dm.txt', 'weighted_unifrac_emperor_pcoa_plot', 'weighted_unifrac_pc.txt']
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# ['.DS_Store', 'bray_curtis_dm.txt', 'bray_curtis_emperor_pcoa_plot', 'bray_curtis_pc.txt', 'compare_categories_binary_macroalgal_contact_bray_curtis', 'compare_categories_binary_macroalgal_contact_unweighted_unifrac', 'compare_categories_binary_macroalgal_contact_weighted_unifrac', 'compare_categories_binary_turf_contact_bray_curtis', 'compare_categories_binary_turf_contact_unweighted_unifrac', 'compare_categories_binary_turf_contact_weighted_unifrac', 'compare_categories_cyanobacteria_contact_bray_curtis', 'compare_categories_cyanobacteria_contact_unweighted_unifrac', 'compare_categories_cyanobacteria_contact_weighted_unifrac', 'compare_categories_cyanobacteria_percent_bray_curtis', 'compare_categories_cyanobacteria_percent_unweighted_unifrac', 'compare_categories_cyanobacteria_percent_weighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_bray_curtis', 'compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_field_host_genus_id_bray_curtis', 'compare_categories_field_host_genus_id_unweighted_unifrac', 'compare_categories_field_host_genus_id_weighted_unifrac', 'compare_categories_field_host_name_bray_curtis', 'compare_categories_field_host_name_unweighted_unifrac', 'compare_categories_field_host_name_weighted_unifrac', 'compare_categories_host_clade_sensu_fukami_bray_curtis', 'compare_categories_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_n_macroalgal_contacts_bray_curtis', 'compare_categories_n_macroalgal_contacts_unweighted_unifrac', 'compare_categories_n_macroalgal_contacts_weighted_unifrac', 'compare_categories_photosynthetically_active_radiation_bray_curtis', 'compare_categories_photosynthetically_active_radiation_unweighted_unifrac', 'compare_categories_photosynthetically_active_radiation_weighted_unifrac', 'compare_categories_reef_name.x_bray_curtis', 'compare_categories_reef_name.x_unweighted_unifrac', 'compare_categories_reef_name.x_weighted_unifrac', 'compare_categories_reef_name_bray_curtis', 'compare_categories_reef_name_unweighted_unifrac', 'compare_categories_reef_name_weighted_unifrac', 'compare_categories_turf_contact_percent_bray_curtis', 'compare_categories_turf_contact_percent_unweighted_unifrac', 'compare_categories_turf_contact_percent_weighted_unifrac', 'compare_categories_visibility_bray_curtis', 'compare_categories_visibility_unweighted_unifrac', 'compare_categories_visibility_weighted_unifrac', 'log_20161031173523.txt', 'otu_table_subset_skeleton_even1000.biom', 'unweighted_unifrac_dm.txt', 'unweighted_unifrac_emperor_pcoa_plot', 'unweighted_unifrac_pc.txt', 'weighted_unifrac_dm.txt', 'weighted_unifrac_emperor_pcoa_plot', 'weighted_unifrac_pc.txt']
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# ['.DS_Store', 'bray_curtis_dm.txt', 'bray_curtis_emperor_pcoa_plot', 'bray_curtis_pc.txt', 'compare_categories_binary_macroalgal_contact_bray_curtis', 'compare_categories_binary_macroalgal_contact_unweighted_unifrac', 'compare_categories_binary_macroalgal_contact_weighted_unifrac', 'compare_categories_binary_turf_contact_bray_curtis', 'compare_categories_binary_turf_contact_unweighted_unifrac', 'compare_categories_binary_turf_contact_weighted_unifrac', 'compare_categories_cyanobacteria_contact_bray_curtis', 'compare_categories_cyanobacteria_contact_unweighted_unifrac', 'compare_categories_cyanobacteria_contact_weighted_unifrac', 'compare_categories_cyanobacteria_percent_bray_curtis', 'compare_categories_cyanobacteria_percent_unweighted_unifrac', 'compare_categories_cyanobacteria_percent_weighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_bray_curtis', 'compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_field_host_genus_id_bray_curtis', 'compare_categories_field_host_genus_id_unweighted_unifrac', 'compare_categories_field_host_genus_id_weighted_unifrac', 'compare_categories_field_host_name_bray_curtis', 'compare_categories_field_host_name_unweighted_unifrac', 'compare_categories_field_host_name_weighted_unifrac', 'compare_categories_host_clade_sensu_fukami_bray_curtis', 'compare_categories_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_n_macroalgal_contacts_bray_curtis', 'compare_categories_n_macroalgal_contacts_unweighted_unifrac', 'compare_categories_n_macroalgal_contacts_weighted_unifrac', 'compare_categories_photosynthetically_active_radiation_bray_curtis', 'compare_categories_photosynthetically_active_radiation_unweighted_unifrac', 'compare_categories_photosynthetically_active_radiation_weighted_unifrac', 'compare_categories_reef_name.x_bray_curtis', 'compare_categories_reef_name.x_unweighted_unifrac', 'compare_categories_reef_name.x_weighted_unifrac', 'compare_categories_reef_name_bray_curtis', 'compare_categories_reef_name_unweighted_unifrac', 'compare_categories_reef_name_weighted_unifrac', 'compare_categories_turf_contact_percent_bray_curtis', 'compare_categories_turf_contact_percent_unweighted_unifrac', 'compare_categories_turf_contact_percent_weighted_unifrac', 'compare_categories_visibility_bray_curtis', 'compare_categories_visibility_unweighted_unifrac', 'compare_categories_visibility_weighted_unifrac', 'log_20161031173800.txt', 'otu_table_subset_tissue_even1000.biom', 'unweighted_unifrac_dm.txt', 'unweighted_unifrac_emperor_pcoa_plot', 'unweighted_unifrac_pc.txt', 'weighted_unifrac_dm.txt', 'weighted_unifrac_emperor_pcoa_plot', 'weighted_unifrac_pc.txt']
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-18-610c8a8f4274> in <module>()
#       8 #    curr_bdiv_dir = join(tissue_otu_table_dir,'bdiv_%s' %c)
#       9     curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
# ---> 10     print listdir(curr_bdiv_dir)
#      11     curr_otu_table = join(tissue_otu_table_dir,c)
#      12     for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
#
# OSError: [Errno 20] Not a directory: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/compartment_tables/otu_table_subset_mucus.biom'

# %% [markdown]
# # Test for differences among functional groups

# %%
#Check for differences among mapping categories within a given compartment
tissue_otu_table_dir = join(output_dir,"compartment_tables")

n_permutations = 1000
categories = 'functional_group_sensu_darling'
for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
#    curr_bdiv_dir = join(tissue_otu_table_dir,'bdiv_%s' %c)
    curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
    print listdir(curr_bdiv_dir)
    curr_otu_table = join(tissue_otu_table_dir,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)   
        for curr_cat in categories.split(","):
            print "curr_cat: %s" %curr_cat
            print "curr_metric: %s" %metric
            print "curr_category: %s" %c
            curr_compare_cat_output_dir = join(curr_bdiv_dir,"compare_categories_%s_%s" %(curr_cat,metric))
            # !compare_categories.py -i $curr_dm -o $curr_compare_cat_output_dir -m $mapping -c $curr_cat --method adonis -n $n_permutations
            the_result = join(curr_compare_cat_output_dir,"adonis_results.txt")
            # !head -n 30 $the_result
# Out:
# ['.DS_Store', 'bray_curtis_dm.txt', 'bray_curtis_emperor_pcoa_plot', 'bray_curtis_pc.txt', 'compare_categories_binary_macroalgal_contact_bray_curtis', 'compare_categories_binary_macroalgal_contact_unweighted_unifrac', 'compare_categories_binary_macroalgal_contact_weighted_unifrac', 'compare_categories_binary_turf_contact_bray_curtis', 'compare_categories_binary_turf_contact_unweighted_unifrac', 'compare_categories_binary_turf_contact_weighted_unifrac', 'compare_categories_cyanobacteria_contact_bray_curtis', 'compare_categories_cyanobacteria_contact_unweighted_unifrac', 'compare_categories_cyanobacteria_contact_weighted_unifrac', 'compare_categories_cyanobacteria_percent_bray_curtis', 'compare_categories_cyanobacteria_percent_unweighted_unifrac', 'compare_categories_cyanobacteria_percent_weighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_bray_curtis', 'compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_field_host_genus_id_bray_curtis', 'compare_categories_field_host_genus_id_unweighted_unifrac', 'compare_categories_field_host_genus_id_weighted_unifrac', 'compare_categories_field_host_name_bray_curtis', 'compare_categories_field_host_name_unweighted_unifrac', 'compare_categories_field_host_name_weighted_unifrac', 'compare_categories_host_clade_sensu_fukami_bray_curtis', 'compare_categories_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_n_macroalgal_contacts_bray_curtis', 'compare_categories_n_macroalgal_contacts_unweighted_unifrac', 'compare_categories_n_macroalgal_contacts_weighted_unifrac', 'compare_categories_photosynthetically_active_radiation_bray_curtis', 'compare_categories_photosynthetically_active_radiation_unweighted_unifrac', 'compare_categories_photosynthetically_active_radiation_weighted_unifrac', 'compare_categories_reef_name.x_bray_curtis', 'compare_categories_reef_name.x_unweighted_unifrac', 'compare_categories_reef_name.x_weighted_unifrac', 'compare_categories_reef_name_bray_curtis', 'compare_categories_reef_name_unweighted_unifrac', 'compare_categories_reef_name_weighted_unifrac', 'compare_categories_turf_contact_percent_bray_curtis', 'compare_categories_turf_contact_percent_unweighted_unifrac', 'compare_categories_turf_contact_percent_weighted_unifrac', 'compare_categories_visibility_bray_curtis', 'compare_categories_visibility_unweighted_unifrac', 'compare_categories_visibility_weighted_unifrac', 'distance_boxplots_all_within_bray_curtis', 'distance_boxplots_all_within_unweighted_unifrac', 'distance_boxplots_all_within_weighted_unifrac', 'distance_boxplots_bray_curtis', 'distance_boxplots_unweighted_unifrac', 'distance_boxplots_weighted_unifrac', 'log_20161031170530.txt', 'otu_table_subset_mucus_even1000.biom', 'unweighted_unifrac_dm.txt', 'unweighted_unifrac_emperor_pcoa_plot', 'unweighted_unifrac_pc.txt', 'weighted_unifrac_dm.txt', 'weighted_unifrac_emperor_pcoa_plot', 'weighted_unifrac_pc.txt']
# curr_cat: functional_group_sensu_darling
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_mucus.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   4     2.508 0.62704  1.4646 0.02818 0.000999
# Residuals                       202    86.485 0.42814         0.97182
# Total                           206    88.993                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: functional_group_sensu_darling
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_mucus.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   4     1.409 0.35234  1.7057 0.03267 0.006993
# Residuals                       202    41.727 0.20657         0.96733
# Total                           206    43.136                 1.00000
#
# qiime.data$map[[opts$category]] **
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: functional_group_sensu_darling
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_mucus.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   4     1.786 0.44653  1.2606 0.02435 0.005994
# Residuals                       202    71.553 0.35422         0.97565
# Total                           206    73.340                 1.00000
#
# qiime.data$map[[opts$category]] **
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ['.DS_Store', 'bray_curtis_dm.txt', 'bray_curtis_emperor_pcoa_plot', 'bray_curtis_pc.txt', 'compare_categories_binary_macroalgal_contact_bray_curtis', 'compare_categories_binary_macroalgal_contact_unweighted_unifrac', 'compare_categories_binary_macroalgal_contact_weighted_unifrac', 'compare_categories_binary_turf_contact_bray_curtis', 'compare_categories_binary_turf_contact_unweighted_unifrac', 'compare_categories_binary_turf_contact_weighted_unifrac', 'compare_categories_cyanobacteria_contact_bray_curtis', 'compare_categories_cyanobacteria_contact_unweighted_unifrac', 'compare_categories_cyanobacteria_contact_weighted_unifrac', 'compare_categories_cyanobacteria_percent_bray_curtis', 'compare_categories_cyanobacteria_percent_unweighted_unifrac', 'compare_categories_cyanobacteria_percent_weighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_bray_curtis', 'compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_field_host_genus_id_bray_curtis', 'compare_categories_field_host_genus_id_unweighted_unifrac', 'compare_categories_field_host_genus_id_weighted_unifrac', 'compare_categories_field_host_name_bray_curtis', 'compare_categories_field_host_name_unweighted_unifrac', 'compare_categories_field_host_name_weighted_unifrac', 'compare_categories_host_clade_sensu_fukami_bray_curtis', 'compare_categories_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_n_macroalgal_contacts_bray_curtis', 'compare_categories_n_macroalgal_contacts_unweighted_unifrac', 'compare_categories_n_macroalgal_contacts_weighted_unifrac', 'compare_categories_photosynthetically_active_radiation_bray_curtis', 'compare_categories_photosynthetically_active_radiation_unweighted_unifrac', 'compare_categories_photosynthetically_active_radiation_weighted_unifrac', 'compare_categories_reef_name.x_bray_curtis', 'compare_categories_reef_name.x_unweighted_unifrac', 'compare_categories_reef_name.x_weighted_unifrac', 'compare_categories_reef_name_bray_curtis', 'compare_categories_reef_name_unweighted_unifrac', 'compare_categories_reef_name_weighted_unifrac', 'compare_categories_turf_contact_percent_bray_curtis', 'compare_categories_turf_contact_percent_unweighted_unifrac', 'compare_categories_turf_contact_percent_weighted_unifrac', 'compare_categories_visibility_bray_curtis', 'compare_categories_visibility_unweighted_unifrac', 'compare_categories_visibility_weighted_unifrac', 'distance_boxplots_all_within_bray_curtis', 'distance_boxplots_all_within_unweighted_unifrac', 'distance_boxplots_all_within_weighted_unifrac', 'distance_boxplots_bray_curtis', 'distance_boxplots_unweighted_unifrac', 'distance_boxplots_weighted_unifrac', 'log_20161031170717.txt', 'otu_table_subset_scleractinian_even1000.biom', 'unweighted_unifrac_dm.txt', 'unweighted_unifrac_emperor_pcoa_plot', 'unweighted_unifrac_pc.txt', 'weighted_unifrac_dm.txt', 'weighted_unifrac_emperor_pcoa_plot', 'weighted_unifrac_pc.txt']
# curr_cat: functional_group_sensu_darling
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   4     7.446 1.86152  4.0162 0.02566 0.000999
# Residuals                       610   282.739 0.46351         0.97434
# Total                           614   290.185                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: functional_group_sensu_darling
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   4     7.756 1.93902  7.6966 0.04804 0.000999
# Residuals                       610   153.679 0.25193         0.95196
# Total                           614   161.435                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: functional_group_sensu_darling
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_scleractinian.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model     R2   Pr(>F)
# qiime.data$map[[opts$category]]   4     7.218 1.80456  4.7981 0.0305 0.000999
# Residuals                       610   229.417 0.37609         0.9695
# Total                           614   236.636                 1.0000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ['.DS_Store', 'bray_curtis_dm.txt', 'bray_curtis_emperor_pcoa_plot', 'bray_curtis_pc.txt', 'compare_categories_binary_macroalgal_contact_bray_curtis', 'compare_categories_binary_macroalgal_contact_unweighted_unifrac', 'compare_categories_binary_macroalgal_contact_weighted_unifrac', 'compare_categories_binary_turf_contact_bray_curtis', 'compare_categories_binary_turf_contact_unweighted_unifrac', 'compare_categories_binary_turf_contact_weighted_unifrac', 'compare_categories_cyanobacteria_contact_bray_curtis', 'compare_categories_cyanobacteria_contact_unweighted_unifrac', 'compare_categories_cyanobacteria_contact_weighted_unifrac', 'compare_categories_cyanobacteria_percent_bray_curtis', 'compare_categories_cyanobacteria_percent_unweighted_unifrac', 'compare_categories_cyanobacteria_percent_weighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_bray_curtis', 'compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_field_host_genus_id_bray_curtis', 'compare_categories_field_host_genus_id_unweighted_unifrac', 'compare_categories_field_host_genus_id_weighted_unifrac', 'compare_categories_field_host_name_bray_curtis', 'compare_categories_field_host_name_unweighted_unifrac', 'compare_categories_field_host_name_weighted_unifrac', 'compare_categories_host_clade_sensu_fukami_bray_curtis', 'compare_categories_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_n_macroalgal_contacts_bray_curtis', 'compare_categories_n_macroalgal_contacts_unweighted_unifrac', 'compare_categories_n_macroalgal_contacts_weighted_unifrac', 'compare_categories_photosynthetically_active_radiation_bray_curtis', 'compare_categories_photosynthetically_active_radiation_unweighted_unifrac', 'compare_categories_photosynthetically_active_radiation_weighted_unifrac', 'compare_categories_reef_name.x_bray_curtis', 'compare_categories_reef_name.x_unweighted_unifrac', 'compare_categories_reef_name.x_weighted_unifrac', 'compare_categories_reef_name_bray_curtis', 'compare_categories_reef_name_unweighted_unifrac', 'compare_categories_reef_name_weighted_unifrac', 'compare_categories_turf_contact_percent_bray_curtis', 'compare_categories_turf_contact_percent_unweighted_unifrac', 'compare_categories_turf_contact_percent_weighted_unifrac', 'compare_categories_visibility_bray_curtis', 'compare_categories_visibility_unweighted_unifrac', 'compare_categories_visibility_weighted_unifrac', 'distance_boxplots_all_within_bray_curtis', 'distance_boxplots_all_within_unweighted_unifrac', 'distance_boxplots_all_within_weighted_unifrac', 'distance_boxplots_bray_curtis', 'distance_boxplots_unweighted_unifrac', 'distance_boxplots_weighted_unifrac', 'log_20161031173523.txt', 'otu_table_subset_skeleton_even1000.biom', 'unweighted_unifrac_dm.txt', 'unweighted_unifrac_emperor_pcoa_plot', 'unweighted_unifrac_pc.txt', 'weighted_unifrac_dm.txt', 'weighted_unifrac_emperor_pcoa_plot', 'weighted_unifrac_pc.txt']
# curr_cat: functional_group_sensu_darling
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_skeleton.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   4     5.259 1.31477  2.9008 0.05407 0.000999
# Residuals                       203    92.009 0.45325         0.94593
# Total                           207    97.268                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: functional_group_sensu_darling
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_skeleton.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   4     6.159 1.53973  6.5765 0.11472 0.000999
# Residuals                       203    47.528 0.23413         0.88528
# Total                           207    53.687                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: functional_group_sensu_darling
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_skeleton.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   4     5.688 1.42212  3.8743 0.07093 0.000999
# Residuals                       203    74.515 0.36707         0.92907
# Total                           207    80.203                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ['.DS_Store', 'bray_curtis_dm.txt', 'bray_curtis_emperor_pcoa_plot', 'bray_curtis_pc.txt', 'compare_categories_binary_macroalgal_contact_bray_curtis', 'compare_categories_binary_macroalgal_contact_unweighted_unifrac', 'compare_categories_binary_macroalgal_contact_weighted_unifrac', 'compare_categories_binary_turf_contact_bray_curtis', 'compare_categories_binary_turf_contact_unweighted_unifrac', 'compare_categories_binary_turf_contact_weighted_unifrac', 'compare_categories_cyanobacteria_contact_bray_curtis', 'compare_categories_cyanobacteria_contact_unweighted_unifrac', 'compare_categories_cyanobacteria_contact_weighted_unifrac', 'compare_categories_cyanobacteria_percent_bray_curtis', 'compare_categories_cyanobacteria_percent_unweighted_unifrac', 'compare_categories_cyanobacteria_percent_weighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_bray_curtis', 'compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_field_host_genus_id_bray_curtis', 'compare_categories_field_host_genus_id_unweighted_unifrac', 'compare_categories_field_host_genus_id_weighted_unifrac', 'compare_categories_field_host_name_bray_curtis', 'compare_categories_field_host_name_unweighted_unifrac', 'compare_categories_field_host_name_weighted_unifrac', 'compare_categories_host_clade_sensu_fukami_bray_curtis', 'compare_categories_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_n_macroalgal_contacts_bray_curtis', 'compare_categories_n_macroalgal_contacts_unweighted_unifrac', 'compare_categories_n_macroalgal_contacts_weighted_unifrac', 'compare_categories_photosynthetically_active_radiation_bray_curtis', 'compare_categories_photosynthetically_active_radiation_unweighted_unifrac', 'compare_categories_photosynthetically_active_radiation_weighted_unifrac', 'compare_categories_reef_name.x_bray_curtis', 'compare_categories_reef_name.x_unweighted_unifrac', 'compare_categories_reef_name.x_weighted_unifrac', 'compare_categories_reef_name_bray_curtis', 'compare_categories_reef_name_unweighted_unifrac', 'compare_categories_reef_name_weighted_unifrac', 'compare_categories_turf_contact_percent_bray_curtis', 'compare_categories_turf_contact_percent_unweighted_unifrac', 'compare_categories_turf_contact_percent_weighted_unifrac', 'compare_categories_visibility_bray_curtis', 'compare_categories_visibility_unweighted_unifrac', 'compare_categories_visibility_weighted_unifrac', 'distance_boxplots_all_within_bray_curtis', 'distance_boxplots_all_within_unweighted_unifrac', 'distance_boxplots_all_within_weighted_unifrac', 'distance_boxplots_bray_curtis', 'distance_boxplots_unweighted_unifrac', 'distance_boxplots_weighted_unifrac', 'log_20161031173800.txt', 'otu_table_subset_tissue_even1000.biom', 'unweighted_unifrac_dm.txt', 'unweighted_unifrac_emperor_pcoa_plot', 'unweighted_unifrac_pc.txt', 'weighted_unifrac_dm.txt', 'weighted_unifrac_emperor_pcoa_plot', 'weighted_unifrac_pc.txt']
# curr_cat: functional_group_sensu_darling
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   4     5.740 1.43505  3.1833 0.06159 0.000999
# Residuals                       194    87.457 0.45081         0.93841
# Total                           198    93.197                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: functional_group_sensu_darling
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   4     5.957  1.4893  5.9641 0.10951 0.000999
# Residuals                       194    48.443  0.2497         0.89049
# Total                           198    54.400                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: functional_group_sensu_darling
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   4     5.046 1.26140  3.4653 0.06669 0.000999
# Residuals                       194    70.617 0.36401         0.93331
# Total                           198    75.663                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-ad9480c91b22> in <module>()
#       9 #    curr_bdiv_dir = join(tissue_otu_table_dir,'bdiv_%s' %c)
#      10     curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
# ---> 11     print listdir(curr_bdiv_dir)
#      12     curr_otu_table = join(tissue_otu_table_dir,c)
#      13     for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
#
# OSError: [Errno 20] Not a directory: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/compartment_tables/otu_table_subset_mucus.biom'

# %%
#Boxplot summaries:
tissue_otu_table_dir = join(output_dir,"compartment_tables")
n_permutations = 1000
categories = 'functional_group_sensu_darling'
for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
#    curr_bdiv_dir = join(tissue_otu_table_dir,'bdiv_%s' %c)
    curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
    print listdir(curr_bdiv_dir)
    curr_otu_table = join(tissue_otu_table_dir,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_all_within_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_individual_within  -n $n_permutations --sort median
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_all_within --suppress_all_between -n $n_permutations --sort median
# Out:
# ['.DS_Store', 'bray_curtis_dm.txt', 'bray_curtis_emperor_pcoa_plot', 'bray_curtis_pc.txt', 'compare_categories_binary_macroalgal_contact_bray_curtis', 'compare_categories_binary_macroalgal_contact_unweighted_unifrac', 'compare_categories_binary_macroalgal_contact_weighted_unifrac', 'compare_categories_binary_turf_contact_bray_curtis', 'compare_categories_binary_turf_contact_unweighted_unifrac', 'compare_categories_binary_turf_contact_weighted_unifrac', 'compare_categories_cyanobacteria_contact_bray_curtis', 'compare_categories_cyanobacteria_contact_unweighted_unifrac', 'compare_categories_cyanobacteria_contact_weighted_unifrac', 'compare_categories_cyanobacteria_percent_bray_curtis', 'compare_categories_cyanobacteria_percent_unweighted_unifrac', 'compare_categories_cyanobacteria_percent_weighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_bray_curtis', 'compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_field_host_genus_id_bray_curtis', 'compare_categories_field_host_genus_id_unweighted_unifrac', 'compare_categories_field_host_genus_id_weighted_unifrac', 'compare_categories_field_host_name_bray_curtis', 'compare_categories_field_host_name_unweighted_unifrac', 'compare_categories_field_host_name_weighted_unifrac', 'compare_categories_functional_group_sensu_darling_bray_curtis', 'compare_categories_functional_group_sensu_darling_unweighted_unifrac', 'compare_categories_functional_group_sensu_darling_weighted_unifrac', 'compare_categories_host_clade_sensu_fukami_bray_curtis', 'compare_categories_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_n_macroalgal_contacts_bray_curtis', 'compare_categories_n_macroalgal_contacts_unweighted_unifrac', 'compare_categories_n_macroalgal_contacts_weighted_unifrac', 'compare_categories_photosynthetically_active_radiation_bray_curtis', 'compare_categories_photosynthetically_active_radiation_unweighted_unifrac', 'compare_categories_photosynthetically_active_radiation_weighted_unifrac', 'compare_categories_reef_name.x_bray_curtis', 'compare_categories_reef_name.x_unweighted_unifrac', 'compare_categories_reef_name.x_weighted_unifrac', 'compare_categories_reef_name_bray_curtis', 'compare_categories_reef_name_unweighted_unifrac', 'compare_categories_reef_name_weighted_unifrac', 'compare_categories_turf_contact_percent_bray_curtis', 'compare_categories_turf_contact_percent_unweighted_unifrac', 'compare_categories_turf_contact_percent_weighted_unifrac', 'compare_categories_visibility_bray_curtis', 'compare_categories_visibility_unweighted_unifrac', 'compare_categories_visibility_weighted_unifrac', 'distance_boxplots_all_within_bray_curtis', 'distance_boxplots_all_within_unweighted_unifrac', 'distance_boxplots_all_within_weighted_unifrac', 'distance_boxplots_bray_curtis', 'distance_boxplots_unweighted_unifrac', 'distance_boxplots_weighted_unifrac', 'log_20161031170530.txt', 'otu_table_subset_mucus_even1000.biom', 'unweighted_unifrac_dm.txt', 'unweighted_unifrac_emperor_pcoa_plot', 'unweighted_unifrac_pc.txt', 'weighted_unifrac_dm.txt', 'weighted_unifrac_emperor_pcoa_plot', 'weighted_unifrac_pc.txt']
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# ['.DS_Store', 'bray_curtis_dm.txt', 'bray_curtis_emperor_pcoa_plot', 'bray_curtis_pc.txt', 'compare_categories_binary_macroalgal_contact_bray_curtis', 'compare_categories_binary_macroalgal_contact_unweighted_unifrac', 'compare_categories_binary_macroalgal_contact_weighted_unifrac', 'compare_categories_binary_turf_contact_bray_curtis', 'compare_categories_binary_turf_contact_unweighted_unifrac', 'compare_categories_binary_turf_contact_weighted_unifrac', 'compare_categories_cyanobacteria_contact_bray_curtis', 'compare_categories_cyanobacteria_contact_unweighted_unifrac', 'compare_categories_cyanobacteria_contact_weighted_unifrac', 'compare_categories_cyanobacteria_percent_bray_curtis', 'compare_categories_cyanobacteria_percent_unweighted_unifrac', 'compare_categories_cyanobacteria_percent_weighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_bray_curtis', 'compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_field_host_genus_id_bray_curtis', 'compare_categories_field_host_genus_id_unweighted_unifrac', 'compare_categories_field_host_genus_id_weighted_unifrac', 'compare_categories_field_host_name_bray_curtis', 'compare_categories_field_host_name_unweighted_unifrac', 'compare_categories_field_host_name_weighted_unifrac', 'compare_categories_functional_group_sensu_darling_bray_curtis', 'compare_categories_functional_group_sensu_darling_unweighted_unifrac', 'compare_categories_functional_group_sensu_darling_weighted_unifrac', 'compare_categories_host_clade_sensu_fukami_bray_curtis', 'compare_categories_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_n_macroalgal_contacts_bray_curtis', 'compare_categories_n_macroalgal_contacts_unweighted_unifrac', 'compare_categories_n_macroalgal_contacts_weighted_unifrac', 'compare_categories_photosynthetically_active_radiation_bray_curtis', 'compare_categories_photosynthetically_active_radiation_unweighted_unifrac', 'compare_categories_photosynthetically_active_radiation_weighted_unifrac', 'compare_categories_reef_name.x_bray_curtis', 'compare_categories_reef_name.x_unweighted_unifrac', 'compare_categories_reef_name.x_weighted_unifrac', 'compare_categories_reef_name_bray_curtis', 'compare_categories_reef_name_unweighted_unifrac', 'compare_categories_reef_name_weighted_unifrac', 'compare_categories_turf_contact_percent_bray_curtis', 'compare_categories_turf_contact_percent_unweighted_unifrac', 'compare_categories_turf_contact_percent_weighted_unifrac', 'compare_categories_visibility_bray_curtis', 'compare_categories_visibility_unweighted_unifrac', 'compare_categories_visibility_weighted_unifrac', 'distance_boxplots_all_within_bray_curtis', 'distance_boxplots_all_within_unweighted_unifrac', 'distance_boxplots_all_within_weighted_unifrac', 'distance_boxplots_bray_curtis', 'distance_boxplots_unweighted_unifrac', 'distance_boxplots_weighted_unifrac', 'log_20161031170717.txt', 'otu_table_subset_scleractinian_even1000.biom', 'unweighted_unifrac_dm.txt', 'unweighted_unifrac_emperor_pcoa_plot', 'unweighted_unifrac_pc.txt', 'weighted_unifrac_dm.txt', 'weighted_unifrac_emperor_pcoa_plot', 'weighted_unifrac_pc.txt']
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# ['.DS_Store', 'bray_curtis_dm.txt', 'bray_curtis_emperor_pcoa_plot', 'bray_curtis_pc.txt', 'compare_categories_binary_macroalgal_contact_bray_curtis', 'compare_categories_binary_macroalgal_contact_unweighted_unifrac', 'compare_categories_binary_macroalgal_contact_weighted_unifrac', 'compare_categories_binary_turf_contact_bray_curtis', 'compare_categories_binary_turf_contact_unweighted_unifrac', 'compare_categories_binary_turf_contact_weighted_unifrac', 'compare_categories_cyanobacteria_contact_bray_curtis', 'compare_categories_cyanobacteria_contact_unweighted_unifrac', 'compare_categories_cyanobacteria_contact_weighted_unifrac', 'compare_categories_cyanobacteria_percent_bray_curtis', 'compare_categories_cyanobacteria_percent_unweighted_unifrac', 'compare_categories_cyanobacteria_percent_weighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_bray_curtis', 'compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_field_host_genus_id_bray_curtis', 'compare_categories_field_host_genus_id_unweighted_unifrac', 'compare_categories_field_host_genus_id_weighted_unifrac', 'compare_categories_field_host_name_bray_curtis', 'compare_categories_field_host_name_unweighted_unifrac', 'compare_categories_field_host_name_weighted_unifrac', 'compare_categories_functional_group_sensu_darling_bray_curtis', 'compare_categories_functional_group_sensu_darling_unweighted_unifrac', 'compare_categories_functional_group_sensu_darling_weighted_unifrac', 'compare_categories_host_clade_sensu_fukami_bray_curtis', 'compare_categories_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_n_macroalgal_contacts_bray_curtis', 'compare_categories_n_macroalgal_contacts_unweighted_unifrac', 'compare_categories_n_macroalgal_contacts_weighted_unifrac', 'compare_categories_photosynthetically_active_radiation_bray_curtis', 'compare_categories_photosynthetically_active_radiation_unweighted_unifrac', 'compare_categories_photosynthetically_active_radiation_weighted_unifrac', 'compare_categories_reef_name.x_bray_curtis', 'compare_categories_reef_name.x_unweighted_unifrac', 'compare_categories_reef_name.x_weighted_unifrac', 'compare_categories_reef_name_bray_curtis', 'compare_categories_reef_name_unweighted_unifrac', 'compare_categories_reef_name_weighted_unifrac', 'compare_categories_turf_contact_percent_bray_curtis', 'compare_categories_turf_contact_percent_unweighted_unifrac', 'compare_categories_turf_contact_percent_weighted_unifrac', 'compare_categories_visibility_bray_curtis', 'compare_categories_visibility_unweighted_unifrac', 'compare_categories_visibility_weighted_unifrac', 'distance_boxplots_all_within_bray_curtis', 'distance_boxplots_all_within_unweighted_unifrac', 'distance_boxplots_all_within_weighted_unifrac', 'distance_boxplots_bray_curtis', 'distance_boxplots_unweighted_unifrac', 'distance_boxplots_weighted_unifrac', 'log_20161031173523.txt', 'otu_table_subset_skeleton_even1000.biom', 'unweighted_unifrac_dm.txt', 'unweighted_unifrac_emperor_pcoa_plot', 'unweighted_unifrac_pc.txt', 'weighted_unifrac_dm.txt', 'weighted_unifrac_emperor_pcoa_plot', 'weighted_unifrac_pc.txt']
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# ['.DS_Store', 'bray_curtis_dm.txt', 'bray_curtis_emperor_pcoa_plot', 'bray_curtis_pc.txt', 'compare_categories_binary_macroalgal_contact_bray_curtis', 'compare_categories_binary_macroalgal_contact_unweighted_unifrac', 'compare_categories_binary_macroalgal_contact_weighted_unifrac', 'compare_categories_binary_turf_contact_bray_curtis', 'compare_categories_binary_turf_contact_unweighted_unifrac', 'compare_categories_binary_turf_contact_weighted_unifrac', 'compare_categories_cyanobacteria_contact_bray_curtis', 'compare_categories_cyanobacteria_contact_unweighted_unifrac', 'compare_categories_cyanobacteria_contact_weighted_unifrac', 'compare_categories_cyanobacteria_percent_bray_curtis', 'compare_categories_cyanobacteria_percent_unweighted_unifrac', 'compare_categories_cyanobacteria_percent_weighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_bray_curtis', 'compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_field_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_field_host_genus_id_bray_curtis', 'compare_categories_field_host_genus_id_unweighted_unifrac', 'compare_categories_field_host_genus_id_weighted_unifrac', 'compare_categories_field_host_name_bray_curtis', 'compare_categories_field_host_name_unweighted_unifrac', 'compare_categories_field_host_name_weighted_unifrac', 'compare_categories_functional_group_sensu_darling_bray_curtis', 'compare_categories_functional_group_sensu_darling_unweighted_unifrac', 'compare_categories_functional_group_sensu_darling_weighted_unifrac', 'compare_categories_host_clade_sensu_fukami_bray_curtis', 'compare_categories_host_clade_sensu_fukami_unweighted_unifrac', 'compare_categories_host_clade_sensu_fukami_weighted_unifrac', 'compare_categories_n_macroalgal_contacts_bray_curtis', 'compare_categories_n_macroalgal_contacts_unweighted_unifrac', 'compare_categories_n_macroalgal_contacts_weighted_unifrac', 'compare_categories_photosynthetically_active_radiation_bray_curtis', 'compare_categories_photosynthetically_active_radiation_unweighted_unifrac', 'compare_categories_photosynthetically_active_radiation_weighted_unifrac', 'compare_categories_reef_name.x_bray_curtis', 'compare_categories_reef_name.x_unweighted_unifrac', 'compare_categories_reef_name.x_weighted_unifrac', 'compare_categories_reef_name_bray_curtis', 'compare_categories_reef_name_unweighted_unifrac', 'compare_categories_reef_name_weighted_unifrac', 'compare_categories_turf_contact_percent_bray_curtis', 'compare_categories_turf_contact_percent_unweighted_unifrac', 'compare_categories_turf_contact_percent_weighted_unifrac', 'compare_categories_visibility_bray_curtis', 'compare_categories_visibility_unweighted_unifrac', 'compare_categories_visibility_weighted_unifrac', 'distance_boxplots_all_within_bray_curtis', 'distance_boxplots_all_within_unweighted_unifrac', 'distance_boxplots_all_within_weighted_unifrac', 'distance_boxplots_bray_curtis', 'distance_boxplots_unweighted_unifrac', 'distance_boxplots_weighted_unifrac', 'log_20161031173800.txt', 'otu_table_subset_tissue_even1000.biom', 'unweighted_unifrac_dm.txt', 'unweighted_unifrac_emperor_pcoa_plot', 'unweighted_unifrac_pc.txt', 'weighted_unifrac_dm.txt', 'weighted_unifrac_emperor_pcoa_plot', 'weighted_unifrac_pc.txt']
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-51990cc96656> in <module>()
#       8 #    curr_bdiv_dir = join(tissue_otu_table_dir,'bdiv_%s' %c)
#       9     curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
# ---> 10     print listdir(curr_bdiv_dir)
#      11     curr_otu_table = join(tissue_otu_table_dir,c)
#      12     for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
#
# OSError: [Errno 20] Not a directory: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/compartment_tables/otu_table_subset_mucus.biom'

# %%
#Test for differences in all samples (i.e. not partioned by compartment). This is useful for identifying differences among compartments.
categories = 'BiologicalMatter,tissue_compartment,host_clade_sensu_fukami,reef_name,field_host_name,field_host_genus_id,photosynthetically_active_radiation,visibility,turf_contact_percent,n_macroalgal_contacts,cyanobacteria_percent,cyanobacteria_contact,binary_turf_contact,binary_macroalgal_contact'
for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
    curr_boxplot_output_dir = join(bdiv_dir_all,"distance_boxplots_%s" %metric)
    curr_dm = join(bdiv_dir_all,"%s_dm.txt" %metric)
    # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_all_within --suppress_all_between -n $n_permutations --sort median

# %%
#Run beta diversity on all samples in dataset rarified to 1000 reads
tissue_otu_table_dir = join(output_dir,"bdiv_all")
depth = 1000

for c in listdir(tissue_otu_table_dir):
    if not c.endswith(".biom"):
        continue
    curr_bdiv_dir = join(output_dir,'bdiv_%s' %c)
    curr_otu_table = join(tissue_otu_table_dir,c)

# !beta_diversity_through_plots.py -i $curr_otu_table -o $curr_bdiv_dir -m $mapping -p $bc_prefs_fp -e $depth -f -t $tree_fp

# %%
#Convert unrarified BIOM to CSV for manipulation in PRIMER
# !biom convert -i $input_dir/otu_table_mc2_wtax_no_pynast_failures_no_organelles.biom -o $input_dir/otu_table_mc2_wtax_no_pynast_failures_no_organelles_TXT.txt --to-tsv --header-key taxonomy

# %%
#Convert rarified (1000) BIOM to CSV for manipulation in PRIMER
# !biom convert -i $output_dir/bdiv_otu_table_mc2_wtax_no_pynast_failures_no_organelles_even1000.biom/otu_table_mc2_wtax_no_pynast_failures_no_organelles_even1000.biom -o $input_dir/otu_table_mc2_wtax_no_pynast_failures_no_organelles_even1000_TXT.txt --to-tsv --header-key taxonomy

# %% [markdown]
# # Test for significant differences in community composition among coral compartments

# %%
#Test for significant differences among coral compartments
# !compare_categories.py --method adonis -i output/bdiv_all/unweighted_unifrac_dm.txt -m input/gcmp16S_map_r20.txt -c BiologicalMatter -o output/significance_testing_compartments/compare_categories_compartments_unweighted_unifrac_adonis.txt -n 999

# %%
#Explore which OTUs differ significantly among compartments
# !group_significance.py -i input/otu_table_mc2_wtax_no_pynast_failures_no_organelles_coral_tissue_mucus_skeleton_only.biom -m input/gcmp16S_map_r20.txt -c BiologicalMatter -s g_test -o output/significance_testing_compartments/group_significance_OTU_BiologicalMatter_g_test.txt
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/qiime/stats.py:1247: RuntimeWarning: divide by zero encountered in double_scalars
#   q = 1. + (a + 1.) / (6. * n)

# %% [markdown]
# # Does host genus drives microbiome structure in brooders to a greater extent than spawners? We will also look at reef and season.

# %%
#Set file paths
input_dir = abspath("input/")
otu_table = abspath("input/otu_table_mc2_wtax_no_pynast_failures_no_organelles.biom")
tree_fp = abspath("input/rep_set.tre")
mapping = abspath("input/gcmp16S_map.txt")
output_dir = abspath("output/")

#Set file paths
input_dir = abspath("input/")
otu_table = abspath("input/otu_table_mc2_wtax_no_pynast_failures_no_organelles.biom")
tree_fp = abspath("input/rep_set.tre")
mapping = abspath("input/gcmp16S_map_r20.txt")
output_dir = abspath("output/")

# %%
#Split OTU table into brooder- and spawner-specific biom files
subset_output = join(output_dir,'brooder_v_spawner')
# !filter_samples_from_otu_table.py -i $otu_table -o $subset_output/otu_table_subset_brooder.biom -m $mapping -s 'Mode_of_larval_development:brooder'
# !filter_samples_from_otu_table.py -i $otu_table -o $subset_output/otu_table_subset_spawner.biom -m $mapping -s 'Mode_of_larval_development:spawner'

# %%
#Export Sceleractinian coral compartment specific biom files (i.e. coral t, m and s) for brooders
subset_output = join(output_dir,'brooder_v_spawner')
brooder_otu_table = join(subset_output,'otu_table_subset_brooder.biom')
spawner_otu_table = join(subset_output,'otu_table_subset_spawner.biom')
#Export Sceleractinian coral compartment specific biom files (i.e. coral t, m and s) for brooders
# !filter_samples_from_otu_table.py -i $brooder_otu_table -o $subset_output/otu_table_subset_brooder_mucus.biom -m $mapping -s 'BiologicalMatter:Coral Mucus'
# !filter_samples_from_otu_table.py -i $brooder_otu_table -o $subset_output/otu_table_subset_brooder_skeleton.biom -m $mapping -s 'BiologicalMatter:Coral Skeleton'
# !filter_samples_from_otu_table.py -i $brooder_otu_table -o $subset_output/otu_table_subset_brooder_tissue.biom -m $mapping -s 'BiologicalMatter:Coral Tissue'
#Export Sceleractinian coral compartment specific biom files (i.e. coral t, m and s) for spawners
# !filter_samples_from_otu_table.py -i $spawner_otu_table -o $subset_output/otu_table_subset_spawner_mucus.biom -m $mapping -s 'BiologicalMatter:Coral Mucus'
# !filter_samples_from_otu_table.py -i $spawner_otu_table -o $subset_output/otu_table_subset_spawner_skeleton.biom -m $mapping -s 'BiologicalMatter:Coral Skeleton'
# !filter_samples_from_otu_table.py -i $spawner_otu_table -o $subset_output/otu_table_subset_spawner_tissue.biom -m $mapping -s 'BiologicalMatter:Coral Tissue'

# %%
#Summarize BIOM to confirm filter functioned correctly
subset_output = join(output_dir,'brooder_v_spawner')
# !biom summarize-table -i $subset_output/otu_table_subset_brooder_mucus.biom -o $subset_output/otu_table_subset_brooder_mucus_summary.txt
# !biom summarize-table -i $subset_output/otu_table_subset_brooder_skeleton.biom -o $subset_output/otu_table_subset_brooder_skeleton_summary.txt
# !biom summarize-table -i $subset_output/otu_table_subset_brooder_tissue.biom -o $subset_output/otu_table_subset_brooder_tissue_summary.txt

# !biom summarize-table -i $subset_output/otu_table_subset_spawner_mucus.biom -o $subset_output/otu_table_subset_spawner_mucus_summary.txt
# !biom summarize-table -i $subset_output/otu_table_subset_spawner_skeleton.biom -o $subset_output/otu_table_subset_spawner_skeleton_summary.txt
# !biom summarize-table -i $subset_output/otu_table_subset_spawner_tissue.biom -o $subset_output/otu_table_subset_spawner_tissue_summary.txt

# %% [markdown]
# #Looks good!

# %%
#Run beta diversity on rarified (1000) subset of each sample type
tissue_otu_table_dir = join(output_dir,"brooder_v_spawner")
depth = 1000

for c in listdir(tissue_otu_table_dir):
    if not c.endswith(".biom"):
        continue
    curr_bdiv_dir = join(tissue_otu_table_dir,'bdiv_%s' %c)
    curr_otu_table = join(tissue_otu_table_dir,c)
    print(curr_otu_table)
    # !beta_diversity_through_plots.py -i $curr_otu_table -o $curr_bdiv_dir -m $mapping -p $bc_prefs_fp -e $depth -f -t $tree_fp
# Out:
# /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_brooder.biom
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0412282144692 and the largest is 3.13193392707.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0579053952104 and the largest is 1.99439774237.
#   RuntimeWarning
# /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_brooder_mucus.biom
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_brooder_skeleton.biom
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.00477819038945 and the largest is 1.51279918088.
#   RuntimeWarning
# /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_brooder_tissue.biom
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0125366593789 and the largest is 1.62546157568.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.00536576056968 and the largest is 0.545835871795.
#   RuntimeWarning
# /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner.biom
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.129330573672 and the largest is 10.7675230558.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.510264543752 and the largest is 14.6681864957.
#   RuntimeWarning
# /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_mucus.biom
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0352210408835 and the largest is 6.01557564504.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.119477033685 and the largest is 6.80736188985.
#   RuntimeWarning
# /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_skeleton.biom
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0853420629271 and the largest is 3.52993370452.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.179626778374 and the largest is 7.92810281431.
#   RuntimeWarning
# /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0258044802679 and the largest is 4.10679319982.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.132583047246 and the largest is 5.24913276903.
#   RuntimeWarning

# %%
#Check for differences among mapping categories within a given compartment
tissue_otu_table_dir = join(output_dir,"brooder_v_spawner")

n_permutations = 1000
categories = 'field_host_clade_sensu_fukami,reef_name.x,field_host_name,field_host_genus_id'
for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
    curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
 #   print listdir(curr_bdiv_dir)
    curr_otu_table = join(tissue_otu_table_dir,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)   
        for curr_cat in categories.split(","):
            print "curr_cat: %s" %curr_cat
            print "curr_metric: %s" %metric
            print "curr_category: %s" %c
            curr_compare_cat_output_dir = join(curr_bdiv_dir,"compare_categories_%s_%s" %(curr_cat,metric))
            # !compare_categories.py -i $curr_dm -o $curr_compare_cat_output_dir -m $mapping -c $curr_cat --method adonis -n $n_permutations
            the_result = join(curr_compare_cat_output_dir,"adonis_results.txt")
            # !head -n 30 $the_result
# Out:
# curr_cat: field_host_clade_sensu_fukami
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_brooder.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  1    2.2918 2.29178  5.6962 0.09873 0.000999
# Residuals                       52   20.9213 0.40233         0.90127
# Total                           53   23.2131                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: reef_name.x
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_brooder.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  4    4.0682 1.01704   2.603 0.17525 0.000999
# Residuals                       49   19.1449 0.39071         0.82475
# Total                           53   23.2131                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_name
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_brooder.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  2    3.3865 1.69323  4.3555 0.14589 0.000999
# Residuals                       51   19.8266 0.38876         0.85411
# Total                           53   23.2131                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_genus_id
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_brooder.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  2    3.3865 1.69323  4.3555 0.14589 0.000999
# Residuals                       51   19.8266 0.38876         0.85411
# Total                           53   23.2131                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_clade_sensu_fukami
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_brooder.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model     R2   Pr(>F)
# qiime.data$map[[opts$category]]  1    0.5117 0.51174  2.3023 0.0424 0.006993 **
# Residuals                       52   11.5581 0.22227         0.9576
# Total                           53   12.0699                 1.0000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: reef_name.x
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_brooder.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  4    1.5385 0.38463  1.7896 0.12747 0.000999
# Residuals                       49   10.5313 0.21493         0.87253
# Total                           53   12.0699                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_name
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_brooder.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  2    1.1709 0.58543  2.7394 0.09701 0.000999
# Residuals                       51   10.8990 0.21371         0.90299
# Total                           53   12.0699                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_genus_id
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_brooder.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  2    1.1709 0.58543  2.7394 0.09701 0.000999
# Residuals                       51   10.8990 0.21371         0.90299
# Total                           53   12.0699                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_clade_sensu_fukami
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_brooder.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  1     0.704 0.70397  2.0673 0.03823 0.000999
# Residuals                       52    17.708 0.34053         0.96177
# Total                           53    18.412                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: reef_name.x
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_brooder.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  4    1.9585 0.48963  1.4582 0.10637 0.000999
# Residuals                       49   16.4532 0.33578         0.89363
# Total                           53   18.4117                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_name
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_brooder.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  2    1.2463 0.62317  1.8515 0.06769 0.000999
# Residuals                       51   17.1654 0.33658         0.93231
# Total                           53   18.4117                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_genus_id
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_brooder.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  2    1.2463 0.62317  1.8515 0.06769 0.000999
# Residuals                       51   17.1654 0.33658         0.93231
# Total                           53   18.4117                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_clade_sensu_fukami
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_brooder_mucus.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_spawner.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  19    10.729 0.56469  1.5218 0.07512 0.000999
# Residuals                       356   132.104 0.37108         0.92488
# Total                           375   142.833                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: field_host_name
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_spawner.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  26    17.758 0.68300  1.9058 0.12433 0.000999
# Residuals                       349   125.076 0.35838         0.87567
# ...
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_spawner_skeleton.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_skeleton.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_skeleton.biom/compare_categories_reef_name.x_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: field_host_name
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_spawner_skeleton.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_skeleton.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_skeleton.biom/compare_categories_field_host_name_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: field_host_genus_id
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_spawner_skeleton.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_skeleton.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_skeleton.biom/compare_categories_field_host_genus_id_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: field_host_clade_sensu_fukami
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_spawner_skeleton.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_skeleton.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_skeleton.biom/compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: reef_name.x
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_spawner_skeleton.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_skeleton.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_skeleton.biom/compare_categories_reef_name.x_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: field_host_name
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_spawner_skeleton.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_skeleton.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_skeleton.biom/compare_categories_field_host_name_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: field_host_genus_id
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_spawner_skeleton.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_skeleton.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_skeleton.biom/compare_categories_field_host_genus_id_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: field_host_clade_sensu_fukami
# curr_metric: bray_curtis
# curr_category: otu_table_subset_spawner_tissue.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/compare_categories_field_host_clade_sensu_fukami_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: reef_name.x
# curr_metric: bray_curtis
# curr_category: otu_table_subset_spawner_tissue.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/compare_categories_reef_name.x_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: field_host_name
# curr_metric: bray_curtis
# curr_category: otu_table_subset_spawner_tissue.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/compare_categories_field_host_name_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: field_host_genus_id
# curr_metric: bray_curtis
# curr_category: otu_table_subset_spawner_tissue.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/compare_categories_field_host_genus_id_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: field_host_clade_sensu_fukami
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_spawner_tissue.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/compare_categories_field_host_clade_sensu_fukami_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: reef_name.x
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_spawner_tissue.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/compare_categories_reef_name.x_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: field_host_name
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_spawner_tissue.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/compare_categories_field_host_name_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: field_host_genus_id
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_spawner_tissue.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/compare_categories_field_host_genus_id_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: field_host_clade_sensu_fukami
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_spawner_tissue.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/compare_categories_field_host_clade_sensu_fukami_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: reef_name.x
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_spawner_tissue.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/compare_categories_reef_name.x_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: field_host_name
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_spawner_tissue.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/compare_categories_field_host_name_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: field_host_genus_id
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_spawner_tissue.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/brooder_v_spawner/otu_table_subset_spawner_tissue.biom/compare_categories_field_host_genus_id_unweighted_unifrac/adonis_results.txt: Not a directory

# %% [markdown]
# # We see significant correlations between alpha diversity and 1) latitude and 2) proportion of max colony size. These effects are most pronounced in stress-tolerant corals. Here, we will see if overall community structure changes 1) along latitudinal gradient and 2) as corals grow larger.

# %%
#Set file paths
input_dir = abspath("input/")
otu_table = abspath("input/otu_table_mc2_wtax_no_pynast_failures_no_organelles.biom")
tree_fp = abspath("input/rep_set.tre")
mapping = abspath("input/gcmp16S_map_r20.txt")
output_dir = abspath("output/")

# %%
#Split OTU table into different functional groups
subset_output = join(output_dir,'functional_groups')
# !filter_samples_from_otu_table.py -i $otu_table -o $subset_output/otu_table_subset_generalist.biom -m $mapping -s 'functional_group_sensu_darling:Generalist'
# !filter_samples_from_otu_table.py -i $otu_table -o $subset_output/otu_table_subset_competitive.biom -m $mapping -s 'functional_group_sensu_darling:Competitive'
# !filter_samples_from_otu_table.py -i $otu_table -o $subset_output/otu_table_subset_stress_tolerant.biom -m $mapping -s 'functional_group_sensu_darling:Stress-tolerant'
# !filter_samples_from_otu_table.py -i $otu_table -o $subset_output/otu_table_subset_weedy.biom -m $mapping -s 'functional_group_sensu_darling:Weedy'

# %%
#Summarize BIOM to confirm filter functioned correctly
subset_output = join(output_dir,'functional_groups')
# !biom summarize-table -i $subset_output/otu_table_subset_generalist.biom -o $subset_output/otu_table_subset_generalist.txt
# !biom summarize-table -i $subset_output/otu_table_subset_competitive.biom -o $subset_output/otu_table_subset_competitive.txt
# !biom summarize-table -i $subset_output/otu_t able_subset_stress_tolerant.biom -o $subset_output/otu_table_subset_stress_tolerant.txt
# !biom summarize-table -i $subset_output/otu_table_subset_weedy.biom -o $subset_output/otu_table_subset_weedy.txt

# %% [markdown]
# #Looks good!

# %%
#Run beta diversity on rarified (1000) subset of each sample type
tissue_otu_table_dir = join(output_dir,'functional_groups')
depth = 1000

for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
    curr_bdiv_dir = join(tissue_otu_table_dir,'bdiv_%s' %c)
    curr_otu_table = join(tissue_otu_table_dir,c)
    print(curr_otu_table)
    # !beta_diversity_through_plots.py -i $curr_otu_table -o $curr_bdiv_dir -m $mapping -p $bc_prefs_fp -e $depth -f -t $tree_fp
# Out:
# /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.00741759659045 and the largest is 3.42543681733.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0534624286624 and the largest is 3.60220386107.
#   RuntimeWarning
# /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.00426119158986 and the largest is 2.52518339985.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0279330580674 and the largest is 3.08720378615.
#   RuntimeWarning
# /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0943930219986 and the largest is 7.68100544672.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.35954414476 and the largest is 14.1307473814.
#   RuntimeWarning
# /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0417159752951 and the largest is 5.5945087651.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0748657297364 and the largest is 2.68518614475.
#   RuntimeWarning

# %%
#Check for differences among mapping categories within a given functional group
tissue_otu_table_dir = join(output_dir,"functional_groups")

n_permutations = 1000
categories = 'prop_Colony_maximum_diameter_universal,latitude,longitude'
for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
    curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
#    print listdir(curr_bdiv_dir)
    curr_otu_table = join(tissue_otu_table_dir,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)   
        for curr_cat in categories.split(","):
            print "curr_cat: %s" %curr_cat
            print "curr_metric: %s" %metric
            print "curr_category: %s" %c
            curr_compare_cat_output_dir = join(curr_bdiv_dir,"compare_categories_%s_%s" %(curr_cat,metric))
            # !compare_categories.py -i $curr_dm -o $curr_compare_cat_output_dir -m $mapping -c $curr_cat --method adonis -n $n_permutations
            the_result = join(curr_compare_cat_output_dir,"adonis_results.txt")
            # !head -n 30 $the_result
# Out:
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_competitive.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2  Pr(>F)
# qiime.data$map[[opts$category]] 23    11.243 0.48881   1.113 0.32989 0.01499 *
# Residuals                       52    22.837 0.43917         0.67011
# Total                           75    34.079                 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: latitude
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_competitive.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]] 12     8.065 0.67208  1.6276 0.23665 0.000999
# Residuals                       63    26.015 0.41293         0.76335
# Total                           75    34.079                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: longitude
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_competitive.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]] 12     8.065 0.67208  1.6276 0.23665 0.000999
# Residuals                       63    26.015 0.41293         0.76335
# Total                           75    34.079                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_competitive.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# qiime.data$map[[opts$category]] 23    5.3402 0.23218   1.019 0.31068 0.4106
# Residuals                       52   11.8484 0.22785         0.68932
# Total                           75   17.1886                 1.00000
# curr_cat: latitude
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_competitive.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]] 12    3.7498 0.31248  1.4649 0.21815 0.002997
# Residuals                       63   13.4389 0.21332         0.78185
# Total                           75   17.1886                 1.00000
#
# qiime.data$map[[opts$category]] **
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: longitude
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_competitive.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]] 12    3.7498 0.31248  1.4649 0.21815 0.000999
# Residuals                       63   13.4389 0.21332         0.78185
# Total                           75   17.1886                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_competitive.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2 Pr(>F)
# qiime.data$map[[opts$category]] 23    8.3365 0.36246  0.9942 0.30543 0.5155
# Residuals                       52   18.9578 0.36457         0.69457
# Total                           75   27.2943                 1.00000
# curr_cat: latitude
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_competitive.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model     R2   Pr(>F)
# qiime.data$map[[opts$category]] 12    4.9295 0.41079  1.1572 0.1806 0.001998 **
# Residuals                       63   22.3649 0.35500         0.8194
# Total                           75   27.2943                 1.0000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: longitude
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_competitive.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model     R2   Pr(>F)
# qiime.data$map[[opts$category]] 12    4.9295 0.41079  1.1572 0.1806 0.001998 **
# Residuals                       63   22.3649 0.35500         0.8194
# Total                           75   27.2943                 1.0000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_generalist.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]] 12    6.9065 0.57554  1.3728 0.32638 0.000999
# Residuals                       34   14.2541 0.41924         0.67362
# Total                           46   21.1606                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: latitude
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_generalist.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model     R2   Pr(>F)
# qiime.data$map[[opts$category]
 1.00000
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: latitude
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_weedy.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  7    2.7217 0.38882  1.9246 0.18589 0.001998
# Residuals                       59   11.9197 0.20203         0.81411
# Total                           66   14.6414                 1.00000
#
# qiime.data$map[[opts$category]] **
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: longitude
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_weedy.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  7    2.7217 0.38882  1.9246 0.18589 0.000999
# Residuals                       59   11.9197 0.20203         0.81411
# Total                           66   14.6414                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_weedy.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]] 18    7.4096 0.41165  1.2081 0.31178 0.000999
# Residuals                       48   16.3558 0.34075         0.68822
# Total                           66   23.7654                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: latitude
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_weedy.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  7     3.713 0.53042  1.5607 0.15623 0.000999
# Residuals                       59    20.052 0.33987         0.84377
# Total                           66    23.765                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: longitude
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_weedy.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  7     3.713 0.53042  1.5607 0.15623 0.000999
# Residuals                       59    20.052 0.33987         0.84377
# Total                           66    23.765                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: bray_curtis
# curr_category: otu_table_subset_competitive.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/compare_categories_prop_Colony_maximum_diameter_universal_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: latitude
# curr_metric: bray_curtis
# curr_category: otu_table_subset_competitive.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/compare_categories_latitude_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: longitude
# curr_metric: bray_curtis
# curr_category: otu_table_subset_competitive.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/compare_categories_longitude_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_competitive.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/compare_categories_prop_Colony_maximum_diameter_universal_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: latitude
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_competitive.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/compare_categories_latitude_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: longitude
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_competitive.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/compare_categories_longitude_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_competitive.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/compare_categories_prop_Colony_maximum_diameter_universal_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: latitude
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_competitive.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/compare_categories_latitude_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: longitude
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_competitive.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/compare_categories_longitude_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: bray_curtis
# curr_category: otu_table_subset_generalist.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/compare_categories_prop_Colony_maximum_diameter_universal_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: latitude
# curr_metric: bray_curtis
# curr_category: otu_table_subset_generalist.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/compare_categories_latitude_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: longitude
# curr_metric: bray_curtis
# curr_category: otu_table_subset_generalist.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/compare_categories_longitude_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_generalist.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/compare_categories_prop_Colony_maximum_diameter_universal_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: latitude
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_generalist.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/compare_categories_latitude_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: longitude
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_generalist.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/compare_categories_longitude_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_generalist.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/compare_categories_prop_Colony_maximum_diameter_universal_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: latitude
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_generalist.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/compare_categories_latitude_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: longitude
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_generalist.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/compare_categories_longitude_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: bray_curtis
# curr_category: otu_table_subset_stress_tolerant.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/compare_categories_prop_Colony_maximum_diameter_universal_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: latitude
# curr_metric: bray_curtis
# curr_category: otu_table_subset_stress_tolerant.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/compare_categories_latitude_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: longitude
# curr_metric: bray_curtis
# curr_category: otu_table_subset_stress_tolerant.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/compare_categories_longitude_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_stress_tolerant.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/compare_categories_prop_Colony_maximum_diameter_universal_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: latitude
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_stress_tolerant.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/compare_categories_latitude_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: longitude
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_stress_tolerant.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/compare_categories_longitude_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_stress_tolerant.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/compare_categories_prop_Colony_maximum_diameter_universal_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: latitude
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_stress_tolerant.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/compare_categories_latitude_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: longitude
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_stress_tolerant.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/compare_categories_longitude_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: bray_curtis
# curr_category: otu_table_subset_weedy.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/compare_categories_prop_Colony_maximum_diameter_universal_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: latitude
# curr_metric: bray_curtis
# curr_category: otu_table_subset_weedy.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/compare_categories_latitude_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: longitude
# curr_metric: bray_curtis
# curr_category: otu_table_subset_weedy.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/compare_categories_longitude_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_weedy.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/compare_categories_prop_Colony_maximum_diameter_universal_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: latitude
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_weedy.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/compare_categories_latitude_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: longitude
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_weedy.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/compare_categories_longitude_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: prop_Colony_maximum_diameter_universal
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_weedy.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/compare_categories_prop_Colony_maximum_diameter_universal_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: latitude
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_weedy.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/compare_categories_latitude_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: longitude
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_weedy.biom
# Error in compare_categories.py: option -i: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/compare_categories_longitude_unweighted_unifrac/adonis_results.txt: Not a directory

# %%
#Boxplot summaries:
tissue_otu_table_dir = join(output_dir,"functional_groups")
n_permutations = 1000
categories = 'prop_Colony_maximum_diameter_universal,latitude,longitude'
for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
    curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
#    print listdir(curr_bdiv_dir)
#    curr_otu_table = join(tissue_otu_table_dir,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_all_within_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_individual_within  -n $n_permutations --sort median
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_all_within --suppress_all_between -n $n_permutations --sort median
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org

# %% [markdown]
# # Use adonis to explore how much variability in coral microbiome is explained by compartment

# %%
#Export Sceleractinian coral  specific biom file
subset_output = join(output_dir,'coral_only')
# !filter_samples_from_otu_table.py -i $otu_table -o $subset_output/otu_table_coral_only.biom -m $mapping --sample_id_fp input/coral_only.txt --output_mapping_fp $subset_output/otu_table_coral_only_map.txt

# %%
#Summarize BIOM to confirm filter functioned correctly
subset_output = join(output_dir,'coral_only')
# !biom summarize-table -i $subset_output/otu_table_coral_only.biom -o $subset_output/otu_table_coral_only_summary.txt

# %% [markdown]
# #Summaries look good.

# %%
#Run beta diversity on rarified (1000) subset of each sample type
tissue_otu_table_dir = join(output_dir,"coral_only")
depth = 1000

for c in listdir(tissue_otu_table_dir):
    if not c.endswith(".biom"):
        continue
    curr_bdiv_dir = join(tissue_otu_table_dir,'bdiv_%s' %c)
    curr_otu_table = join(tissue_otu_table_dir,c)
    # !beta_diversity_through_plots.py -i $curr_otu_table -o $curr_bdiv_dir -m $mapping -p $bc_prefs_fp -e $depth -f -t $tree_fp
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.192225882455 and the largest is 17.2822267266.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -1.19476909769 and the largest is 22.2380806245.
#   RuntimeWarning

# %%
#Check for differences among mapping categories within a given functional group
tissue_otu_table_dir = join(output_dir,"coral_only")

n_permutations = 1000
categories = 'BiologicalMatter'
for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
    curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
#    print listdir(curr_bdiv_dir)
    curr_otu_table = join(tissue_otu_table_dir,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)   
        for curr_cat in categories.split(","):
            print "curr_cat: %s" %curr_cat
            print "curr_metric: %s" %metric
            print "curr_category: %s" %c
            curr_compare_cat_output_dir = join(curr_bdiv_dir,"compare_categories_%s_%s" %(curr_cat,metric))
            # !compare_categories.py -i $curr_dm -o $curr_compare_cat_output_dir -m $mapping -c $curr_cat --method adonis -n $n_permutations
            the_result = join(curr_compare_cat_output_dir,"adonis_results.txt")
            # !head -n 30 $the_result
# Out:
# curr_cat: BiologicalMatter
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_coral_only.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   2    10.469  5.2344  11.443 0.03538 0.000999
# Residuals                       624   285.434  0.4574         0.96462
# Total                           626   295.903                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: BiologicalMatter
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_coral_only.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   2    11.185  5.5925  20.442 0.06149 0.000999
# Residuals                       624   170.716  0.2736         0.93851
# Total                           626   181.901                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: BiologicalMatter
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_coral_only.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   2     7.248  3.6241  9.8508 0.03061 0.000999
# Residuals                       624   229.568  0.3679         0.96939
# Total                           626   236.816                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: BiologicalMatter
# curr_metric: bray_curtis
# curr_category: otu_table_coral_only.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/compare_categories_BiologicalMatter_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: BiologicalMatter
# curr_metric: weighted_unifrac
# curr_category: otu_table_coral_only.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/compare_categories_BiologicalMatter_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: BiologicalMatter
# curr_metric: unweighted_unifrac
# curr_category: otu_table_coral_only.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/compare_categories_BiologicalMatter_unweighted_unifrac/adonis_results.txt: Not a directory

# %% [markdown]
# # Seasonal variability using only Lizard Island samples

# %%
# Subset Lizard Island samples from sceleractinian coral compartment specific biom files (i.e. coral t, m and s)
subset_output = join(output_dir,'compartment_tables')
lirs_output = join(output_dir,'lizard_island_tables')
# !filter_samples_from_otu_table.py -i $subset_output/otu_table_subset_mucus.biom -o $lirs_output/otu_table_subset_mucus_lirs.biom -m $mapping -s 'site_name:Great_Barrier_Reef_-_Lizard_Island_Sector'
# !filter_samples_from_otu_table.py -i $subset_output/otu_table_subset_skeleton.biom -o $lirs_output/otu_table_subset_skeleton_lirs.biom -m $mapping -s 'site_name:Great_Barrier_Reef_-_Lizard_Island_Sector'
# !filter_samples_from_otu_table.py -i $subset_output/otu_table_subset_tissue.biom -o $lirs_output/otu_table_subset_tissue_lirs.biom -m $mapping -s 'site_name:Great_Barrier_Reef_-_Lizard_Island_Sector'

# %%
#Run beta diversity on rarified (1000) subset of each sample type from LIRS
lirs_output = join(output_dir,'lizard_island_tables')
depth = 1000

for c in listdir(lirs_output):
    if not c.endswith(".biom"):
        continue
    curr_bdiv_dir = join(lirs_output,'bdiv_%s' %c)
    curr_otu_table = join(lirs_output,c)
    # !beta_diversity_through_plots.py -i $curr_otu_table -o $curr_bdiv_dir -m $mapping -p $bc_prefs_fp -e $depth -f -t $tree_fp
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0374272131787 and the largest is 5.62637812019.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0859660828597 and the largest is 4.58853552914.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0480181795419 and the largest is 3.32490705344.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.125021274305 and the largest is 6.2473739898.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.py:2507: VisibleDeprecationWarning: `rank` is deprecated; use the `ndim` attribute or function instead. To find the rank of a matrix see `numpy.linalg.matrix_rank`.
#   VisibleDeprecationWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0493280775174 and the largest is 3.7855402424.
#   RuntimeWarning
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:107: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.136379771221 and the largest is 4.68797513675.
#   RuntimeWarning

# %%
#Check for differences among mapping categories within lizard island compartments
lirs_output = join(output_dir,'lizard_island_tables')

n_permutations = 1000
categories = 'expedition_number'
for c in listdir(lirs_output):
    if not c.endswith('.biom'):
        continue
    curr_bdiv_dir = join(lirs_output,'%s' %c)
#    print listdir(curr_bdiv_dir)
    curr_otu_table = join(lirs_output,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)   
        for curr_cat in categories.split(","):
            print "curr_cat: %s" %curr_cat
            print "curr_metric: %s" %metric
            print "curr_category: %s" %c
            curr_compare_cat_output_dir = join(curr_bdiv_dir,"compare_categories_%s_%s" %(curr_cat,metric))
            # !compare_categories.py -i $curr_dm -o $curr_compare_cat_output_dir -m $mapping -c $curr_cat --method adonis -n $n_permutations
            the_result = join(curr_compare_cat_output_dir,"adonis_results.txt")
            # !head -n 30 $the_result
# Out:
# curr_cat: expedition_number
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_mucus_lirs.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   1     3.538  3.5381  9.6083 0.08687 0.000999
# Residuals                       101    37.192  0.3682         0.91313
# Total                           102    40.730                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: expedition_number
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_mucus_lirs.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model    R2   Pr(>F)
# qiime.data$map[[opts$category]]   1    2.1328  2.1328  12.229 0.108 0.000999
# Residuals                       101   17.6149  0.1744         0.892
# Total                           102   19.7477                 1.000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: expedition_number
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_mucus_lirs.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   1     2.072 2.07210  6.2837 0.05857 0.000999
# Residuals                       101    33.305 0.32975         0.94143
# Total                           102    35.377                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: expedition_number
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_skeleton_lirs.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   1     0.963 0.96272  2.0743 0.02032 0.000999
# Residuals                       100    46.412 0.46412         0.97968
# Total                           101    47.375                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: expedition_number
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_skeleton_lirs.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   1     1.035 1.03500  4.0374 0.03881 0.000999
# Residuals                       100    25.635 0.25635         0.96119
# Total                           101    26.670                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: expedition_number
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_skeleton_lirs.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                  Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]   1     0.927 0.92694  2.4084 0.02352 0.001998
# Residuals                       100    38.488 0.38488         0.97648
# Total                           101    39.415                 1.00000
#
# qiime.data$map[[opts$category]] **
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: expedition_number
# curr_metric: bray_curtis
# curr_category: bdiv_otu_table_subset_tissue_lirs.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  1     1.255 1.25514  2.7441 0.02751 0.000999
# Residuals                       97    44.367 0.45739         0.97249
# Total                           98    45.622                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: expedition_number
# curr_metric: weighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue_lirs.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  1    0.8452 0.84520  3.2937 0.03284 0.000999
# Residuals                       97   24.8910 0.25661         0.96716
# Total                           98   25.7362                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: expedition_number
# curr_metric: unweighted_unifrac
# curr_category: bdiv_otu_table_subset_tissue_lirs.biom
#
# Call:
# adonis(formula = as.dist(qiime.data$distmat) ~ qiime.data$map[[opts$category]],      permutations = opts$num_permutations)
#
# Permutation: free
# Number of permutations: 1000
#
# Terms added sequentially (first to last)
#
#                                 Df SumsOfSqs MeanSqs F.Model      R2   Pr(>F)
# qiime.data$map[[opts$category]]  1     1.185 1.18494     3.2 0.03194 0.000999
# Residuals                       97    35.918 0.37029         0.96806
# Total                           98    37.103                 1.00000
#
# qiime.data$map[[opts$category]] ***
# Residuals
# Total
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# curr_cat: expedition_number
# curr_metric: bray_curtis
# curr_category: otu_table_subset_mucus_lirs.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_mucus_lirs.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_mucus_lirs.biom/compare_categories_expedition_number_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: expedition_number
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_mucus_lirs.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_mucus_lirs.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_mucus_lirs.biom/compare_categories_expedition_number_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: expedition_number
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_mucus_lirs.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_mucus_lirs.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_mucus_lirs.biom/compare_categories_expedition_number_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: expedition_number
# curr_metric: bray_curtis
# curr_category: otu_table_subset_skeleton_lirs.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_skeleton_lirs.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_skeleton_lirs.biom/compare_categories_expedition_number_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: expedition_number
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_skeleton_lirs.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_skeleton_lirs.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_skeleton_lirs.biom/compare_categories_expedition_number_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: expedition_number
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_skeleton_lirs.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_skeleton_lirs.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_skeleton_lirs.biom/compare_categories_expedition_number_unweighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: expedition_number
# curr_metric: bray_curtis
# curr_category: otu_table_subset_tissue_lirs.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_tissue_lirs.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_tissue_lirs.biom/compare_categories_expedition_number_bray_curtis/adonis_results.txt: Not a directory
# curr_cat: expedition_number
# curr_metric: weighted_unifrac
# curr_category: otu_table_subset_tissue_lirs.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_tissue_lirs.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_tissue_lirs.biom/compare_categories_expedition_number_weighted_unifrac/adonis_results.txt: Not a directory
# curr_cat: expedition_number
# curr_metric: unweighted_unifrac
# curr_category: otu_table_subset_tissue_lirs.biom
# Error in compare_categories.py: option -i: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_tissue_lirs.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# head: /Users/FJPollock/Dropbox/coral_microbiomes_postdoc/gcmp_osu_psu_shared_folder/coral_microbe_coevolution/Projects/australia_coevolution_paper/16S_analysis/3b_bdiv_australia_analysis/output/lizard_island_tables/otu_table_subset_tissue_lirs.biom/compare_categories_expedition_number_unweighted_unifrac/adonis_results.txt: Not a directory

# %%
#Boxplot summaries:
tissue_otu_table_dir = join(output_dir,"coral_only")
n_permutations = 1000
categories = 'BiologicalMatter'
for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
    curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
#    print listdir(curr_bdiv_dir)
#    curr_otu_table = join(tissue_otu_table_dir,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_all_within_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_individual_within  -n $n_permutations --sort median
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_all_within --suppress_all_between -n $n_permutations --sort median

# %% [markdown]
# # Explore differences in traunches of latitude (latitude_traunch) and prop_Colony_maximum_diameter_universal (prop_Colony_maximum_diameter_universal_traunch)

# %% [markdown]
# #Trauches added in "input/gcmp16S_map_r20_lat_size_traunches.txt"

# %%
#Boxplot summaries w/in all corals:
mapping = abspath("input/gcmp16S_map_r20_lat_size_traunches.txt")

tissue_otu_table_dir = join(output_dir,"coral_only")
n_permutations = 1000
categories = 'latitude_traunch,prop_Colony_maximum_diameter_universal_traunch'
for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
    curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
#    print listdir(curr_bdiv_dir)
#    curr_otu_table = join(tissue_otu_table_dir,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_all_within_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_individual_within  -n $n_permutations --sort median
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_all_within --suppress_all_between -n $n_permutations --sort median
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/temp.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/temp.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/temp.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/temp.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/temp.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/temp.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org

# %%
#Boxplot summaries w/in tissue compartment:
mapping = abspath("input/gcmp16S_map_r20_lat_size_traunches.txt")

tissue_otu_table_dir = join(output_dir,"compartment_tables")
n_permutations = 1000
categories = 'latitude_traunch,prop_Colony_maximum_diameter_universal_traunch'
for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
    curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
#    print listdir(curr_bdiv_dir)
#    curr_otu_table = join(tissue_otu_table_dir,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_all_within_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_individual_within  -n $n_permutations --sort median
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_all_within --suppress_all_between -n $n_permutations --sort median
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_mucus.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_mucus.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_mucus.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_mucus.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_mucus.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_mucus.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_skeleton.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_skeleton.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_skeleton.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_skeleton.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_skeleton.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_skeleton.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_tissue.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_tissue.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_tissue.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_tissue.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_tissue.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_tissue.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org

# %%
#Boxplot summaries w/in functional groups:
mapping = abspath("input/gcmp16S_map_r20_lat_size_traunches.txt")

tissue_otu_table_dir = join(output_dir,"functional_groups")
n_permutations = 1000
categories = 'latitude_traunch,prop_Colony_maximum_diameter_universal_traunch'
for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
    curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
#    print listdir(curr_bdiv_dir)
#    curr_otu_table = join(tissue_otu_table_dir,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_all_within_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_individual_within  -n $n_permutations --sort median
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_all_within --suppress_all_between -n $n_permutations --sort median
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org

# %%
#Boxplot summaries w/in all corals for compartment differences:
mapping = abspath("input/gcmp16S_map_r20_lat_size_traunches.txt")

tissue_otu_table_dir = join(output_dir,"coral_only")
n_permutations = 1000
categories = 'BiologicalMatter'
for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
    curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
#    print listdir(curr_bdiv_dir)
#    curr_otu_table = join(tissue_otu_table_dir,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_all_within_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_individual_within  -n $n_permutations --sort median
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_all_within --suppress_all_between -n $n_permutations --sort median
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/coral_only/otu_table_coral_only.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org

# %%
#Boxplot summaries w/in brooders and spawners:
mapping = abspath("input/gcmp16S_map_r20_lat_size_traunches.txt")

tissue_otu_table_dir = join(output_dir,"functional_groups")
n_permutations = 1000
categories = 'latitude_traunch,prop_Colony_maximum_diameter_universal_traunch'
for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
    curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
#    print listdir(curr_bdiv_dir)
#    curr_otu_table = join(tissue_otu_table_dir,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_all_within_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_individual_within  -n $n_permutations --sort median
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_all_within --suppress_all_between -n $n_permutations --sort median
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/skbio/draw/_distributions.py:701: RuntimeWarning: Could not automatically resize plot to make room for axes labels and plot title. This can happen if the labels or title are extremely long and the plot size is too small. Your plot may have its labels and/or title cut-off. To fix this, try increasing the plot's size (in inches) and try again.
#   RuntimeWarning)
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_competitive.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_generalist.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_stress_tolerant.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Volumes/Macintosh_HDD/Dropbox/Coral_Microbiomes_Postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/functional_groups/otu_table_subset_weedy.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org

# %% [markdown]
# # Explore differences in traunches of prop_Colony_maximum_diameter_universal (< 20% vs > 20% max size) w/in compartments...

# %%
#Set file paths
input_dir = abspath("input/")
otu_table = abspath("input/otu_table_mc2_wtax_no_pynast_failures_no_organelles.biom")
tree_fp = abspath("input/rep_set.tre")
mapping = abspath("input/gcmp16S_map_r20.txt")
output_dir = abspath("output/")

# %%
#Boxplot summaries w/in tissue compartment (with raw data save):
mapping = abspath("input/gcmp16S_map_r20_lat_size_traunches.txt")

tissue_otu_table_dir = join(output_dir,"compartment_tables")
n_permutations = 1000
categories = 'latitude_traunch,prop_Colony_maximum_diameter_universal_traunch'
for c in listdir(tissue_otu_table_dir):
    if not c.endswith('.biom'):
        continue
    curr_bdiv_dir = join(tissue_otu_table_dir,'%s' %c)
#    print listdir(curr_bdiv_dir)
#    curr_otu_table = join(tissue_otu_table_dir,c)
    for metric in ['bray_curtis','weighted_unifrac','unweighted_unifrac']:
        curr_dm = join(curr_bdiv_dir,"%s_dm.txt" %metric)
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_all_within_%s" %metric)
#        !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_individual_between --suppress_individual_within  -n $n_permutations --sort median
        curr_boxplot_output_dir = join(curr_bdiv_dir,"distance_boxplots_%s" %metric)
        # !make_distance_boxplots.py -d $curr_dm -o $curr_boxplot_output_dir -m $mapping -f $categories --height 20 --suppress_all_within --suppress_all_between -n $n_permutations --sort median --save_raw_data
# Out:
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_mucus.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_mucus.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_mucus.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_skeleton.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_skeleton.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_skeleton.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_tissue.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_tissue.biom/weighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_tissue.biom/unweighted_unifrac_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# Error in make_distance_boxplots.py: option -d: file does not exist: '/Users/FJPollock/Dropbox/coral_microbiomes_postdoc/GCMP_OSU_PSU_Shared_Folder/Coral_microbe_coevolution/Projects/Australia_Coevolution_Paper/16S_analysis/3b_bdiv_australia_analysis/output/tissue_compartment_tables/otu_table_subset_tissue_1000.biom/bray_curtis_dm.txt'
#
# If you need help with QIIME, see:
# http://help.qiime.org
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")
# /macqiime/anaconda/lib/python2.7/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")

# %% [markdown]
# # With continuous data (i.e. prop_Colony_maximum_diameter_universal,latitude,longitude) it might be better to bin before box plots

# %% [markdown]
# # Could explore any interesting differences deeper by looking within compartments of specific functional groups.

# %%
#Summarize BIOM
# !biom summarize-table -i $otu_table
# Out:
# Num samples: 692
# Num observations: 129305
# Total count: 9441738
# Table density (fraction of non-zero values): 0.006
#
# Counts/sample summary:
#  Min: 2.0
#  Max: 38523.0
#  Median: 14010.000
#  Mean: 13644.130
#  Std. dev.: 7564.457
#  Sample Metadata Categories: None provided
#  Observation Metadata Categories: taxonomy
#
# Counts/sample detail:
#  E7.17.Pla.sine.1.20150622.M: 2.0
#  E3.17.Ech.mamm.1.20150127.S: 3.0
#  E10.17.Fav.pali.2.20150630.T: 5.0
#  E7.17.Fav.spB.1.20150623.T: 7.0
#  E3.17.Ech.horr.1.20150123.M: 8.0
#  E3.15.Dip.heli.2.20150120.T: 9.0
#  E10.Cyp.sera.1.20150628.M: 17.0
#  E10.17.Fav.pali.1.20150630.T: 17.0
#  E3.Out.Mil.sp.2.20150125.M: 24.0
#  E10.17.Fav.pali.1.20150630.M: 36.0
#  E10.17.Fav.pali.2.20150630.S: 41.0
#  E10.Cyp.sera.2.20150628.T: 42.0
#  E1.6.Acr.sp.1.20140726.T: 42.0
#  E3.5.Gal.astr.2.20150127.T: 53.0
#  E10.Ser.cali.2.20150627.T: 66.0
#  E10.Alv.alli.1.20150628.S: 96.0
#  E10.Ser.cali.1.20150627.T: 102.0
#  E10.17.Fav.pali.2.20150630.M: 127.0
#  E10.17.Fav.abdi.2.20150630.T: 165.0
#  E7.17.Gon.edwa.2.20150623.S: 197.0
#  E10.17.Fav.pali.3.20150630.T: 200.0
#  E10.17.Fav.pali.3.20150630.S: 252.0
#  E10.17.Fav.pali.3.20150630.M: 276.0
#  E3.6.Acr.hyac.3.20150106.S: 470.0
#  E10.Ser.cali.3.20150627.T: 522.0
#  E10.10.Sty.pist.2.20150630.S: 566.0
#  E3.6.Acr.hyac.1.20150120.T: 576.0
#  E3.2.Tur.reni.2.20150124.S: 627.0
